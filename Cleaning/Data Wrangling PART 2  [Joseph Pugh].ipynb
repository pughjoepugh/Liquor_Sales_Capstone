# %% [markdown]
# # Data Wrangling Part 2

# %%
# load packages

import pandas as pd
import numpy as np

# %%
# load csv
iowa = pd.read_csv('iowa_clean.csv')
# Out:
# /Users/joe/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22815313 entries, 0 to 22815312
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Date                  object
#  1   City                  object
#  2   Zip Code              int64
#  3   County                object
#  4   Item Number           object
#  5   Item Description      object
#  6   Bottle Volume (ml)    int64
#  7   State Bottle Cost     float64
#  8   State Bottle Retail   float64
#  9   Bottles Sold          int64
#  10  Sale (Dollars)        float64
#  11  Volume Sold (Liters)  float64
#  12  Store Name            object
#  13  Category Name         object
#  14  Category              float64
#  15  Vendor Name           object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 2.7+ GB

# %%
# Attempted to convert item number to int and it failed.
# found the random entry. it was 3 entries
iowa = iowa[iowa['Item Number'] != 'x904631']

# change the data type
iowa['Item Number'] = iowa['Item Number'].astype('int')

# %%
# convert date to date time object
iowa['Date'] = pd.to_datetime(iowa['Date'])

# %% [markdown]
# ## STATE BOTTLE COST

# %%
# let's take a look the numerical categories

iowa['State Bottle Cost'].describe()
# Out:
# count    2.281530e+07
# mean     1.013200e+01
# std      1.078194e+01
# min      0.000000e+00
# 25%      5.510000e+00
# 50%      8.250000e+00
# 75%      1.249000e+01
# max      7.680000e+03
# Name: State Bottle Cost, dtype: float64

# %% [markdown]
# ### Observation:
# 1. Some bottle costs are zero.
# After speaking with some Washington State Liquor Reps. I learned that the only reason an invoice would read 0 cost is for sample bottles or broken/ replacement bottles. Each state has different liquor laws however I will proceed like this rule applies.
# 2. The average cost is $10
# 3. Highest is $7680
# 4. Mode is lower than the mean so the high end has a tail/ outliers. This makes sense. The average cost is $10 and you cannot have a negative price.
#
# I will be removing the zero cost bottles.

# %%
# how often is liquor free?
bottles = iowa[iowa['State Bottle Cost'] != 0.0]
broken = iowa[iowa['State Bottle Cost'] == 0.0]

print('Broken bottle percentage: ', broken['Bottles Sold'].sum() / bottles['Bottles Sold'].sum() * 100)
# Out:
# Broken bottle percentage:  0.007711920987747631

# %% [markdown]
# ### Is 0.007711% a good thing?
# Do warehouse staff or drivers need to be better?
# Do sample bottles lead to sales?
# I do not know, but the number could be used for reference

# %%
# Remove the zero cost bottles. 
iowa = iowa[iowa['State Bottle Cost'] != 0.0]

# %%
# exploring bottle cost.  What is the max outlier?
iowa[iowa['State Bottle Cost'] == iowa['State Bottle Cost'].max()]
# Out:
#                Date          City  Zip Code County  Item Number  \
# 17989104 2016-10-25  CEDAR RAPIDS     52402   LINN       927849
#
#                                       Item Description  Bottle Volume (ml)  \
# 17989104  Cedar Ridge Reserve Bourbon Private Cask DNO                 750
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 17989104             7680.0              11520.0             1
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 17989104         11520.0                  0.75
#
#                                    Store Name   Category Name   Category  \
# 17989104  Hy-vee food store #5 / cedar rapids  BOURBON WHISKY  1011250.0
#
#                         Vendor Name
# 17989104  CEDAR RIDGE VINEYARDS,LLC

# %% [markdown]
# ## CITY

# %%
# CITY column
iowa['City'].value_counts()
# Out:
# DES MOINES        1969961
# CEDAR RAPIDS      1482468
# DAVENPORT          986758
# WATERLOO           726064
# COUNCIL BLUFFS     670957
#                    ...
# EARLING               182
# SIDNEY                178
# CHESTER               171
# MILO                  158
# ALVORD                 10
# Name: City, Length: 452, dtype: int64

# %% [markdown]
# ### Observaiton:
# ALVORD has only 10 entries/ invoices?

# %%
# city of alvord
iowa[iowa['City']== 'ALVORD']
# Out:
#                Date    City  Zip Code County  Item Number  \
# 12151270 2012-01-11  ALVORD     51230   LYON        41076
# 12151271 2012-01-11  ALVORD     51230   LYON        13638
# 12151272 2012-01-11  ALVORD     51230   LYON        11586
# 12151273 2012-01-11  ALVORD     51230   LYON        13636
# 12151274 2012-01-11  ALVORD     51230   LYON        46351
# 12151275 2012-01-11  ALVORD     51230   LYON        43338
# 12151276 2012-01-11  ALVORD     51230   LYON        11777
# 12151277 2012-01-11  ALVORD     51230   LYON        43337
# 12151278 2012-01-11  ALVORD     51230   LYON        76487
# 12151279 2012-01-11  ALVORD     51230   LYON        11788
#
#                        Item Description  Bottle Volume (ml)  \
# 12151270  Jeremiah Weed Sweet Tea Vodka                 750
# 12151271   Lord Calvert Canadian Whisky                1750
# 12151272           Black Velvet Reserve                 750
# 12151273   Lord Calvert Canadian Whisky                 750
# 12151274              Hawkeye Light Rum                1000
# 12151275      Captain Morgan Spiced Rum                1750
# 12151276                   Black Velvet                1000
# 12151277      Captain Morgan Spiced Rum                1000
# 12151278             Paramount Amaretto                1000
# 12151279                   Black Velvet                1750
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 12151270               9.46                14.20             3
# 12151271               9.97                14.95             1
# 12151272               6.75                10.12             4
# 12151273               5.25                 7.87             2
# 12151274               4.22                 6.33            12
# 12151275              16.99                25.48             6
# 12151276               6.63                 9.94            12
# 12151277              10.99                16.49            12
# 12151278               4.04                 6.06             2
# 12151279              10.45                15.67             6
#
#           Sale (Dollars)  Volume Sold (Liters)              Store Name  \
# 12151270           42.60                  2.25  Direct liquor / alvord
# 12151271           14.95                  1.75  Direct liquor / alvord
# 12151272           40.48                  3.00  Direct liquor / alvord
# 12151273           15.74                  1.50  Direct liquor / alvord
# 12151274           75.96                 12.00  Direct liquor / alvord
# 12151275          152.88                 10.50  Direct liquor / alvord
# 12151276          119.28                 12.00  Direct liquor / alvord
# 12151277          197.88                 12.00  Direct liquor / alvord
# 12151278           12.12                  2.00  Direct liquor / alvord
# 12151279           94.02                 10.50  Direct liquor / alvord
#
#             Category Name   Category                       Vendor Name
# 12151270   FLAVORED VODKA  1031200.0                   DIAGEO AMERICAS
# 12151271  CANADIAN WHISKY  1012100.0                    LUXCO-ST LOUIS
# 12151272  CANADIAN WHISKY  1012100.0  CONSTELLATION WINE COMPANY, INC.
# 12151273  CANADIAN WHISKY  1012100.0                    LUXCO-ST LOUIS
# 12151274              RUM  1062400.0                    LUXCO-ST LOUIS
# 12151275              RUM  1062400.0                   DIAGEO AMERICAS
# 12151276  CANADIAN WHISKY  1012100.0  CONSTELLATION WINE COMPANY, INC.
# 12151277              RUM  1062400.0                   DIAGEO AMERICAS
# 12151278          LIQUEUR  1082900.0                    LUXCO-ST LOUIS
# 12151279  CANADIAN WHISKY  1012100.0  CONSTELLATION WINE COMPANY, INC.

# %% [markdown]
# ### Oberservation:
# it appears that this store might have closed. All 10 invoices were from the first month of all data collected and 'direct liquor alvord' doesn't exist on google. I won't delete it because the sales are real.

# %% [markdown]
# ## COUNTY

# %%
# COUNTY
iowa['County'].value_counts()
# Out:
# POLK          4208232
# LINN          1901012
# SCOTT         1397198
# BLACK HAWK    1281301
# JOHNSON       1149129
#                ...
# ADAMS           18664
# WAYNE           17549
# DAVIS           17149
# RINGGOLD        15546
# FREMONT          3567
# Name: County, Length: 99, dtype: int64

# %% [markdown]
# ## CATEGORY

# %%
#CATEGORY NAME
iowa['Category Name'].value_counts()
# Out:
# VODKA                            4648435
# RUM                              2265155
# CANADIAN WHISKY                  2197313
# WHISKY                           2079346
# SCHNAPPS                         1544325
# LIQUEUR                          1442946
# BOURBON WHISKY                   1400309
# BRANDY                           1198734
# FLAVORED VODKA                   1131515
# TEQUILA                          1087101
# FLAVORED WHISKY                   979396
# GIN                               761938
# COCKTAILS RTD                     655518
# SCOTCH                            487698
# FLAVORED RUM                      326540
# SPECIAL PACKAGING                 322171
# RYE WHISKY                        122681
# NEUTRAL GRAIN                      52958
# NEUTRAL GRAIN SPIRIT FLAVORED      42124
# SPECIALTY                          26812
# FLAVORED GIN                       11943
# MEZCAL                              7544
# IOWA LOCAL                          2937
# HIGH BEER                             32
# Name: Category Name, dtype: int64

# %% [markdown]
# ### Observation:
# 1. Vodka is #1 by entries, proving that 'vodka pays the bills'
# 2. Rum is #2? This is surprising however It could be due to different styles
# 3. whisky, whisky but schnapps is 5th?

# %% [markdown]
# ## ITEM DESCRIPTION

# %%
# item description
iowa['Item Description'].value_counts()
# Out:
# Black Velvet                          583803
# Hawkeye Vodka                         507616
# Fireball Cinnamon Whiskey             298683
# Titos Handmade Vodka                  257122
# Five O'clock Vodka                    254808
#                                        ...
# New Amsterdam Citron Flavored              1
# Old Pulteney 12yr Sing Malt Scotch         1
# Mr Boston 5 Star Canadian Whisky           1
# Don Cesar Pisco Puro                       1
# Burnett's  Blackberry  Flav. Vodka         1
# Name: Item Description, Length: 10083, dtype: int64

# %% [markdown]
# ### Observation:
# 1. Black Velvet! Canadian whisky is the single most common item on invoices
# 2. the rest of the top are variations of vodka or whisky

# %%
# What is the most popular item by volume?
group = iowa.groupby('Item Description')['Volume Sold (Liters)'].agg('sum','sum').reset_index()
group.sort_values('Volume Sold (Liters)',ascending=False)
# Out:
#                                Item Description  Volume Sold (Liters)
# 1207                               Black Velvet           13178692.13
# 4633                              Hawkeye Vodka            8586083.34
# 9413                       Titos Handmade Vodka            5649855.32
# 3616                  Fireball Cinnamon Whiskey            4425843.57
# 1940                  Captain Morgan Spiced Rum            4318257.98
# ...                                         ...                   ...
# 6192  Mark and Diggers Rye Apple Moonshine Mini                  0.05
# 7945          Ryder Cup Lemonade Moonshine Mini                  0.05
# 493        Appalachian Apple Pie Moonshine Mini                  0.05
# 8869               Stoli Crushed Pineapple Mini                  0.05
# 1823             Canadian Club Dock 57 Mini DNO                  0.00
#
# [10083 rows x 2 columns]

# %% [markdown]
# ### Observation:
# 1. BLACK VELVET is a clear favorite. with 1.3 M liters of Black Velvet over ~9 years
# 2. Rum did return to the top.

# %% [markdown]
# ## BOTTLE VOLUME

# %%
iowa['Bottle Volume (ml)'].value_counts()
# Out:
# 750       10249803
# 1750       4533531
# 1000       2904417
# 375        2316718
# 200         811182
# 500         722400
# 50          648298
# 600         218660
# 100         149335
# 3000         94403
# 300          93446
# 800          21644
# 1200         19490
# 2400          7904
# 850           3192
# 400           2214
# 1850          1883
# 1800          1760
# 20            1582
# 900           1481
# 6000          1290
# 3500          1122
# 950            864
# 250            858
# 150            789
# 2250           663
# 1950           566
# 4800           476
# 1125           411
# 502            349
# 25             252
# 603            201
# 1500           190
# 5250           178
# 3600           161
# 301            130
# 4500            79
# 1420            63
# 2550            42
# 175             39
# 425             26
# 378000          24
# 31500           24
# 2000            23
# 2125            16
# 3900            15
# 0               10
# 140000           8
# 355              7
# 9000             3
# 1508             3
# 180000           2
# 189000           2
# 7580             1
# 15               1
# 12               1
# 225000           1
# Name: Bottle Volume (ml), dtype: int64

# %% [markdown]
# ### Observation
# There are some weird bottle sizes. Anything that doesn't end in a 0 or 5 is odd. Also bottler size of 0 is odd

# %%
# examine a couple entries: 12, 15, 7580
iowa[(iowa['Bottle Volume (ml)'] == 12) | (iowa['Bottle Volume (ml)'] == 15) | (iowa['Bottle Volume (ml)'] == 7580) ]
# Out:
#                Date             City  Zip Code     County  Item Number  \
# 2003400  2013-09-17         GRINNELL     50112  POWESHIEK       917836
# 3963735  2014-05-12  WEST DES MOINES     50265       POLK       900673
# 16531109 2012-02-16       CORALVILLE     52241    JOHNSON       903158
#
#                       Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 2003400        Early Times Bourbon 354                7580               9.46
# 3963735   Balvenie Trio Pack(12/14/17)                  15               3.55
# 16531109     Westerhall Plantation Rum                  12              33.67
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 2003400                 14.19            12          170.28
# 3963735                  5.33            32          170.56
# 16531109                50.50             6          303.00
#
#           Volume Sold (Liters)                 Store Name   Category Name  \
# 2003400                  90.96       Mcnally's super valu  BOURBON WHISKY
# 3963735                   0.48            Hy-vee #4 / wdm          SCOTCH
# 16531109                  0.07  Bootleggin' barzini's fin             RUM
#
#            Category                   Vendor Name
# 2003400   1011250.0      BROWN-FORMAN CORPORATION
# 3963735   1012210.0  WILLIAM GRANT AND SONS, INC.
# 16531109  1062400.0                       MHW LTD

# %%
#first odd volume size item
iowa[iowa['Item Description'] == 'Early Times Bourbon 354']
# Out:
#               Date        City  Zip Code     County  Item Number  \
# 548321  2012-03-08        AMES     50010      STORY        17836
# 1944213 2012-09-27    GRINNELL     50112  POWESHIEK        17836
# 2003400 2013-09-17    GRINNELL     50112  POWESHIEK       917836
# 4962186 2013-06-03  DES MOINES     50312       POLK        17836
#
#                 Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 548321   Early Times Bourbon 354                 750               9.46
# 1944213  Early Times Bourbon 354                 750               9.46
# 2003400  Early Times Bourbon 354                7580               9.46
# 4962186  Early Times Bourbon 354                 750               9.46
#
#          State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 548321                 14.19            12          170.28
# 1944213                14.19            12          170.28
# 2003400                14.19            12          170.28
# 4962186                14.19            12          170.28
#
#          Volume Sold (Liters)                     Store Name   Category Name  \
# 548321                   9.00                Cyclone liquors  BOURBON WHISKY
# 1944213                  9.00           Mcnally's super valu  BOURBON WHISKY
# 2003400                 90.96           Mcnally's super valu  BOURBON WHISKY
# 4962186                  9.00  Ingersoll liquor and beverage  BOURBON WHISKY
#
#           Category               Vendor Name
# 548321   1011250.0  BROWN-FORMAN CORPORATION
# 1944213  1011250.0  BROWN-FORMAN CORPORATION
# 2003400  1011250.0  BROWN-FORMAN CORPORATION
# 4962186  1011250.0  BROWN-FORMAN CORPORATION

# %%
# after a little investigation 7580 is an error which makes sense. 
# 2gal of bourbon for 14 dollars would make the news

iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(7580, 750)
# Out:
# /var/folders/70/gq6zfpsx5rg7k0vsvcbg70_40000gn/T/ipykernel_86625/1026652849.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(7580, 750)

# %%
# investigating the 12ml bottle that costs $33.67, appears to be incorrect
iowa[iowa['State Bottle Cost'] == 33.67]
# Out:
#                Date         City  Zip Code      County  Item Number  \
# 569239   2014-10-22         AMES     50010       STORY       902551
# 5258099  2014-09-25   DES MOINES     50314        POLK       902551
# 6981415  2015-06-23        CLIVE     50325        POLK       902551
# 9056208  2015-08-06  CEDAR FALLS     50613  BLACK HAWK       902551
# 10033158 2015-02-23     WATERLOO     50701  BLACK HAWK       902551
# 10096127 2016-02-29     WATERLOO     50701  BLACK HAWK       902551
# 16531109 2012-02-16   CORALVILLE     52241     JOHNSON       903158
#
#                             Item Description  Bottle Volume (ml)  \
# 569239    Kammer Williams Pear Brandy W/pear                 750
# 5258099   Kammer Williams Pear Brandy W/pear                 750
# 6981415   Kammer Williams Pear Brandy W/pear                 750
# 9056208   Kammer Williams Pear Brandy W/pear                 750
# 10033158  Kammer Williams Pear Brandy W/pear                 750
# 10096127  Kammer Williams Pear Brandy W/pear                 750
# 16531109           Westerhall Plantation Rum                  12
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 569239                33.67                50.51            12
# 5258099               33.67                50.51            35
# 6981415               33.67                50.51            23
# 9056208               33.67                50.51            12
# 10033158              33.67                50.51            60
# 10096127              33.67                50.51            24
# 16531109              33.67                50.50             6
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 569239            606.12                  9.00
# 5258099          1767.85                 26.25
# 6981415          1161.73                 17.25
# 9056208           606.12                  9.00
# 10033158         3030.60                 45.00
# 10096127         1212.24                 18.00
# 16531109          303.00                  0.07
#
#                                   Store Name Category Name   Category  \
# 569239                       Cyclone liquors       LIQUEUR  1082900.0
# 5258099            Central city liquor, inc.       LIQUEUR  1082900.0
# 6981415               World liquor & tobacco       LIQUEUR  1082900.0
# 9056208               Happy's wine & spirits       LIQUEUR  1082900.0
# 10033158  Hy-vee wine and spirits / waterloo       LIQUEUR  1082900.0
# 10096127  Hy-vee wine and spirits / waterloo       LIQUEUR  1082900.0
# 16531109           Bootleggin' barzini's fin           RUM  1062400.0
#
#                Vendor Name
# 569239    NICHE IMPORT CO.
# 5258099   NICHE IMPORT CO.
# 6981415   NICHE IMPORT CO.
# 9056208   NICHE IMPORT CO.
# 10033158  NICHE IMPORT CO.
# 10096127  NICHE IMPORT CO.
# 16531109           MHW LTD

# %% [markdown]
# Westerhall plantation rum is real. I am going to change it to 750. 750 is by far the most popular bottle size and the price is close

# %%
# correcting the plantation
iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(12, 750)
# Out:
# /var/folders/70/gq6zfpsx5rg7k0vsvcbg70_40000gn/T/ipykernel_86625/759484811.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(12, 750)

# %%
# balvinie three pack is actually 15cl not 15ml. so we will change that to 150ml
iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(15, 150)
# Out:
# /var/folders/70/gq6zfpsx5rg7k0vsvcbg70_40000gn/T/ipykernel_86625/362062135.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(15, 150)

# %%
# another singular bottle size, but a large one
iowa[iowa['Bottle Volume (ml)']== 225000]
# Out:
#                Date          City  Zip Code County  Item Number  \
# 18462369 2016-03-21  CEDAR RAPIDS     52402   LINN       946127
#
#                                  Item Description  Bottle Volume (ml)  \
# 18462369  Cedar Ridge Barrel Aged Rum 5YR Reserve              225000
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 18462369             5500.0               8250.0             1
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 18462369          8250.0                 225.0
#
#                                    Store Name Category Name   Category  \
# 18462369  Hy-vee food store #5 / cedar rapids           RUM  1062400.0
#
#                         Vendor Name
# 18462369  CEDAR RIDGE VINEYARDS,LLC

# %% [markdown]
# ### This appears to be a whole barrel, and the price matches

# %%
# checking the next odd entry, 0
iowa[iowa['Bottle Volume (ml)']== 0]
# Out:
#                Date        City  Zip Code   County  Item Number  \
# 823146   2013-12-11        AMES     50014    STORY       905230
# 3366231  2014-01-29       PELLA     50219   MARION       964590
# 6350915  2014-04-03  DES MOINES     50320     POLK       934962
# 16005684 2014-07-24   IOWA CITY     52240  JOHNSON       934962
# 16042455 2014-04-24   IOWA CITY     52240  JOHNSON       934962
# 16067707 2014-09-17   IOWA CITY     52240  JOHNSON       934962
# 16170005 2014-03-20   IOWA CITY     52240  JOHNSON       934962
# 22588548 2015-05-06   DAVENPORT     52807    SCOTT       941063
# 22595956 2014-05-07   DAVENPORT     52807    SCOTT       941063
# 22693830 2015-11-18   DAVENPORT     52807    SCOTT       941063
#
#                             Item Description  Bottle Volume (ml)  \
# 823146                 Rondiaz DSS Lemon Rum                   0
# 3366231       Canadian Club Dock 57 Mini DNO                   0
# 6350915            Three Olives Orange Vodka                   0
# 16005684           Three Olives Orange Vodka                   0
# 16042455           Three Olives Orange Vodka                   0
# 16067707           Three Olives Orange Vodka                   0
# 16170005           Three Olives Orange Vodka                   0
# 22588548  Burnett's Pink Lemonade Vodka Mini                   0
# 22595956  Burnett's Pink Lemonade Vodka Mini                   0
# 22693830  Burnett's Pink Lemonade Vodka Mini                   0
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 823146                 8.52                12.78            30
# 3366231                4.80                 7.20            12
# 6350915               11.17                16.76            12
# 16005684              11.17                16.76            48
# 16042455              11.17                16.76           120
# 16067707              11.17                16.76            24
# 16170005              11.17                16.76            48
# 22588548               4.25                 6.38            12
# 22595956               4.25                 6.38            12
# 22693830               4.25                 6.38            12
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 823146            383.40                   0.0
# 3366231            86.40                   0.0
# 6350915           201.12                   0.0
# 16005684          804.48                   0.0
# 16042455         2011.20                   0.0
# 16067707          402.24                   0.0
# 16170005          804.48                   0.0
# 22588548           76.56                   0.0
# 22595956           76.56                   0.0
# 22693830           76.56                   0.0
#
#                                    Store Name      Category Name   Category  \
# 823146                     Aj's liquor / ames  SPECIAL PACKAGING  1701200.0
# 3366231       Hy-vee wine and spirits / pella    CANADIAN WHISKY  1012100.0
# 6350915          Hy-vee #3 / bdi / des moines              VODKA  1032230.0
# 16005684  Hy-vee wine and spirits / iowa city              VODKA  1032230.0
# 16042455          Liquor downtown / iowa city              VODKA  1032230.0
# 16067707  Hy-vee wine and spirits / iowa city              VODKA  1032230.0
# 16170005  Hy-vee wine and spirits / iowa city              VODKA  1032230.0
# 22588548         Hy-vee #3 food and drugstore     FLAVORED VODKA  1031200.0
# 22595956         Hy-vee #3 food and drugstore     FLAVORED VODKA  1031200.0
# 22693830         Hy-vee #3 food and drugstore     FLAVORED VODKA  1031200.0
#
#                               Vendor Name
# 823146    PRESTIGE WINE AND SPIRITS GROUP
# 3366231                   JIM BEAM BRANDS
# 6350915                           PROXIMO
# 16005684                          PROXIMO
# 16042455                          PROXIMO
# 16067707                          PROXIMO
# 16170005                          PROXIMO
# 22588548               HEAVEN HILL BRANDS
# 22595956               HEAVEN HILL BRANDS
# 22693830               HEAVEN HILL BRANDS

# %%
# there are 10 entries that have a volume of zero

iowa = iowa[iowa['Bottle Volume (ml)'] != 0]

# %%
# next bottle volume: 140000
iowa[iowa['Bottle Volume (ml)'] == 140000]
# Out:
#                Date             City  Zip Code         County  Item Number  \
# 529833   2014-02-26             AMES     50010          STORY       901645
# 4860315  2014-02-25  WINDSOR HEIGHTS     50311           POLK       901645
# 10263377 2014-03-03         WATERLOO     50702     BLACK HAWK       901645
# 11884608 2014-02-26       SIOUX CITY     51106       WOODBURY       901645
# 13350043 2014-03-03   COUNCIL BLUFFS     51501  POTTAWATTAMIE       901645
# 14809769 2014-02-26          DUBUQUE     52002        DUBUQUE       901645
# 18180186 2014-03-03     CEDAR RAPIDS     52402           LINN       901645
# 22652102 2014-02-26        DAVENPORT     52807          SCOTT       901645
#
#                               Item Description  Bottle Volume (ml)  \
# 529833    Absolut w/ Zing Zang Bloody Mary Mix              140000
# 4860315   Absolut w/ Zing Zang Bloody Mary Mix              140000
# 10263377  Absolut w/ Zing Zang Bloody Mary Mix              140000
# 11884608  Absolut w/ Zing Zang Bloody Mary Mix              140000
# 13350043  Absolut w/ Zing Zang Bloody Mary Mix              140000
# 14809769  Absolut w/ Zing Zang Bloody Mary Mix              140000
# 18180186  Absolut w/ Zing Zang Bloody Mary Mix              140000
# 22652102  Absolut w/ Zing Zang Bloody Mary Mix              140000
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 529833               1599.2               2398.8             1
# 4860315              1599.2               2398.8             1
# 10263377             1599.2               2398.8             1
# 11884608             1599.2               2398.8             1
# 13350043             1599.2               2398.8             1
# 14809769             1599.2               2398.8             1
# 18180186             1599.2               2398.8             2
# 22652102             1599.2               2398.8             2
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 529833            2398.8                 140.0
# 4860315           2398.8                 140.0
# 10263377          2398.8                 140.0
# 11884608          2398.8                 140.0
# 13350043          2398.8                 140.0
# 14809769          2398.8                 140.0
# 18180186          4797.6                 280.0
# 22652102          4797.6                 280.0
#
#                                  Store Name      Category Name   Category  \
# 529833               Sam's club 6568 / ames  SPECIAL PACKAGING  1701200.0
# 4860315   Sam's club 6344 / windsor heights  SPECIAL PACKAGING  1701200.0
# 10263377         Sam's club 6514 / waterloo  SPECIAL PACKAGING  1701200.0
# 11884608       Sam's club 6432 / sioux city  SPECIAL PACKAGING  1701200.0
# 13350043   Sam's club 6472 / council bluffs  SPECIAL PACKAGING  1701200.0
# 14809769          Sam's club 4973 / dubuque  SPECIAL PACKAGING  1701200.0
# 18180186     Sam's club 8162 / cedar rapids  SPECIAL PACKAGING  1701200.0
# 22652102        Sam's club 8238 / davenport  SPECIAL PACKAGING  1701200.0
#
#                                Vendor Name
# 529833    PERNOD RICARD USA/AUSTIN NICHOLS
# 4860315   PERNOD RICARD USA/AUSTIN NICHOLS
# 10263377  PERNOD RICARD USA/AUSTIN NICHOLS
# 11884608  PERNOD RICARD USA/AUSTIN NICHOLS
# 13350043  PERNOD RICARD USA/AUSTIN NICHOLS
# 14809769  PERNOD RICARD USA/AUSTIN NICHOLS
# 18180186  PERNOD RICARD USA/AUSTIN NICHOLS
# 22652102  PERNOD RICARD USA/AUSTIN NICHOLS

# %% [markdown]
# #### 140000 ml appears to be a real entry. they are all the same product and volume and price seem appropriate

# %%
# next bottle volume: 9000
iowa[iowa['Bottle Volume (ml)'] == 9000]
# Out:
#                Date         City  Zip Code      County  Item Number  \
# 9304622  2016-04-28  CEDAR FALLS     50613  BLACK HAWK       935961
# 10673265 2016-04-28     WATERLOO     50703  BLACK HAWK       935961
# 16352572 2016-04-25    IOWA CITY     52240     JOHNSON       935961
#
#          Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 9304622   Pearl Red Berry                9000                7.0
# 10673265  Pearl Red Berry                9000                7.0
# 16352572  Pearl Red Berry                9000                7.0
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 9304622                  10.5            60           630.0
# 10673265                 10.5           120          1260.0
# 16352572                 10.5            12           126.0
#
#           Volume Sold (Liters)                           Store Name  \
# 9304622                  540.0          Hillstreet news and tobacco
# 10673265                1080.0                 Sycamore convenience
# 16352572                 108.0  Hy-vee wine and spirits / iowa city
#
#          Category Name   Category     Vendor Name
# 9304622          VODKA  1032230.0  LUXCO-ST LOUIS
# 10673265         VODKA  1032230.0  LUXCO-ST LOUIS
# 16352572         VODKA  1032230.0  LUXCO-ST LOUIS

# %% [markdown]
# #### 9000 seems off. mainly due to 9L of vodka being sold for $10.50

# %%
# exploring the 9000ml item
iowa[(iowa['Item Description'] == 'Pearl Red Berry') & (iowa['State Bottle Cost'] == 7.0)]
# Out:
#                Date         City  Zip Code      County  Item Number  \
# 6258276  2016-12-05   DES MOINES     50320        POLK       935961
# 6285029  2016-09-19   DES MOINES     50320        POLK       935961
# 6292939  2018-01-29   DES MOINES     50320        POLK       935961
# 8899547  2018-12-28  CEDAR FALLS     50613  BLACK HAWK       935961
# 8938552  2017-05-11  CEDAR FALLS     50613  BLACK HAWK       935961
# 8981810  2018-03-08  CEDAR FALLS     50613  BLACK HAWK       935961
# 8992272  2018-05-31  CEDAR FALLS     50613  BLACK HAWK       935961
# 9304622  2016-04-28  CEDAR FALLS     50613  BLACK HAWK       935961
# 10467820 2017-05-11     WATERLOO     50703  BLACK HAWK       935961
# 10673265 2016-04-28     WATERLOO     50703  BLACK HAWK       935961
# 15956423 2017-11-27    IOWA CITY     52240     JOHNSON       935961
# 15979880 2018-05-07    IOWA CITY     52240     JOHNSON       935961
# 16352572 2016-04-25    IOWA CITY     52240     JOHNSON       935961
# 20739304 2018-03-05   BETTENDORF     52722       SCOTT       935961
#
#          Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 6258276   Pearl Red Berry                 750                7.0
# 6285029   Pearl Red Berry                 750                7.0
# 6292939   Pearl Red Berry                 750                7.0
# 8899547   Pearl Red Berry                 750                7.0
# 8938552   Pearl Red Berry                 750                7.0
# 8981810   Pearl Red Berry                 750                7.0
# 8992272   Pearl Red Berry                 750                7.0
# 9304622   Pearl Red Berry                9000                7.0
# 10467820  Pearl Red Berry                 750                7.0
# 10673265  Pearl Red Berry                9000                7.0
# 15956423  Pearl Red Berry                 750                7.0
# 15979880  Pearl Red Berry                 750                7.0
# 16352572  Pearl Red Berry                9000                7.0
# 20739304  Pearl Red Berry                 750                7.0
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 6258276                  10.5            12           126.0
# 6285029                  10.5            12           126.0
# 6292939                  10.5            12           126.0
# 8899547                  10.5           120          1260.0
# 8938552                  10.5            60           630.0
# 8981810                  10.5            60           630.0
# 8992272                  10.5           120          1260.0
# 9304622                  10.5            60           630.0
# 10467820                 10.5            60           630.0
# 10673265                 10.5           120          1260.0
# 15956423                 10.5            12           126.0
# 15979880                 10.5            12           126.0
# 16352572                 10.5            12           126.0
# 20739304                 10.5            12           126.0
#
#           Volume Sold (Liters)                           Store Name  \
# 6258276                    9.0         Hy-vee #3 / bdi / des moines
# 6285029                    9.0         Hy-vee #3 / bdi / des moines
# 6292939                    9.0         Hy-vee #3 / bdi / des moines
# 8899547                   90.0          Hillstreet news and tobacco
# 8938552                   45.0          Hillstreet news and tobacco
# 8981810                   45.0          Hillstreet news and tobacco
# 8992272                   90.0          Hillstreet news and tobacco
# 9304622                  540.0          Hillstreet news and tobacco
# 10467820                  45.0                 Sycamore convenience
# 10673265                1080.0                 Sycamore convenience
# 15956423                   9.0  Hy-vee wine and spirits / iowa city
# 15979880                   9.0  Hy-vee wine and spirits / iowa city
# 16352572                 108.0  Hy-vee wine and spirits / iowa city
# 20739304                   9.0                        Lot-a-spirits
#
#          Category Name   Category     Vendor Name
# 6258276          VODKA  1032230.0  LUXCO-ST LOUIS
# 6285029          VODKA  1032230.0  LUXCO-ST LOUIS
# 6292939          VODKA  1032230.0  LUXCO-ST LOUIS
# 8899547          VODKA  1032230.0  LUXCO-ST LOUIS
# 8938552          VODKA  1032230.0  LUXCO-ST LOUIS
# 8981810          VODKA  1032230.0  LUXCO-ST LOUIS
# 8992272          VODKA  1032230.0  LUXCO-ST LOUIS
# 9304622          VODKA  1032230.0  LUXCO-ST LOUIS
# 10467820         VODKA  1032230.0  LUXCO-ST LOUIS
# 10673265         VODKA  1032230.0  LUXCO-ST LOUIS
# 15956423         VODKA  1032230.0  LUXCO-ST LOUIS
# 15979880         VODKA  1032230.0  LUXCO-ST LOUIS
# 16352572         VODKA  1032230.0  LUXCO-ST LOUIS
# 20739304         VODKA  1032230.0  LUXCO-ST LOUIS

# %%
# 9000 is supposed to be 750
iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(9000, 750)

# %%
# Bottle volume: 1508
iowa[iowa['Bottle Volume (ml)'] == 1508]
# Out:
#                Date          City  Zip Code   County  Item Number  \
# 16125252 2012-10-01     IOWA CITY     52240  JOHNSON        35261
# 17186553 2012-10-02    MONTICELLO     52310    JONES        35261
# 20254889 2012-10-02  FORT MADISON     52627      LEE        35261
#
#                   Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 16125252  Purus Organic Vodka Mini                1508                4.4
# 17186553  Purus Organic Vodka Mini                1508                4.4
# 20254889  Purus Organic Vodka Mini                1508                4.4
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 16125252                  6.6           132           871.2
# 17186553                  6.6             8            52.8
# 20254889                  6.6             4            26.4
#
#           Volume Sold (Liters)                           Store Name  \
# 16125252                199.06  Hy-vee wine and spirits / iowa city
# 17186553                 12.06     Fareway stores #840 / monticello
# 20254889                  6.03                 Quicker liquor store
#
#          Category Name   Category                        Vendor Name
# 16125252         VODKA  1032230.0  ANHEUSER-BUSCH/LONGTAIL LIBATIONS
# 17186553         VODKA  1032230.0  ANHEUSER-BUSCH/LONGTAIL LIBATIONS
# 20254889         VODKA  1032230.0  ANHEUSER-BUSCH/LONGTAIL LIBATIONS

# %%
# I can tell that something labeled mini is wrong at 1.5L
iowa[(iowa['Item Description'] == 'Purus Organic Vodka Mini')]
# Out:
#                Date          City  Zip Code   County  Item Number  \
# 16125252 2012-10-01     IOWA CITY     52240  JOHNSON        35261
# 17186553 2012-10-02    MONTICELLO     52310    JONES        35261
# 20254889 2012-10-02  FORT MADISON     52627      LEE        35261
#
#                   Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 16125252  Purus Organic Vodka Mini                1508                4.4
# 17186553  Purus Organic Vodka Mini                1508                4.4
# 20254889  Purus Organic Vodka Mini                1508                4.4
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 16125252                  6.6           132           871.2
# 17186553                  6.6             8            52.8
# 20254889                  6.6             4            26.4
#
#           Volume Sold (Liters)                           Store Name  \
# 16125252                199.06  Hy-vee wine and spirits / iowa city
# 17186553                 12.06     Fareway stores #840 / monticello
# 20254889                  6.03                 Quicker liquor store
#
#          Category Name   Category                        Vendor Name
# 16125252         VODKA  1032230.0  ANHEUSER-BUSCH/LONGTAIL LIBATIONS
# 17186553         VODKA  1032230.0  ANHEUSER-BUSCH/LONGTAIL LIBATIONS
# 20254889         VODKA  1032230.0  ANHEUSER-BUSCH/LONGTAIL LIBATIONS

# %% [markdown]
# ### Thoughts
# These are the only entries for Purus Vodka Mini. So I do not have a reference point. I am just going to change them to the standard mini size 50ml, it will be close. The price of $4.4 assures me it is close.

# %%
# make those changes
iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(1508, 50)

# %%
# Bottle volume: 301
iowa[iowa['Bottle Volume (ml)'] == 301]
# Out:
#                Date       City  Zip Code  County  Item Number  \
# 42549    2012-11-05      ALDEN     50006  HARDIN         2928
# 131187   2012-04-12    ALTOONA     50009    POLK         2928
# 137107   2012-02-23    ALTOONA     50009    POLK         2928
# 397583   2012-11-12       AMES     50010   STORY         2928
# 454710   2012-07-19       AMES     50010   STORY         2928
# ...             ...        ...       ...     ...          ...
# 21438615 2012-11-01  LE CLAIRE     52753   SCOTT         2928
# 21439949 2012-06-28  LE CLAIRE     52753   SCOTT         2928
# 21445564 2012-05-31  LE CLAIRE     52753   SCOTT         2928
# 22147102 2012-08-16  DAVENPORT     52804   SCOTT         2928
# 22189771 2012-03-15  DAVENPORT     52804   SCOTT         2928
#
#                           Item Description  Bottle Volume (ml)  \
# 42549     Bacardi Multi-Flavor Mini 6 Pack                 301
# 131187    Bacardi Multi-Flavor Mini 6 Pack                 301
# 137107    Bacardi Multi-Flavor Mini 6 Pack                 301
# 397583    Bacardi Multi-Flavor Mini 6 Pack                 301
# 454710    Bacardi Multi-Flavor Mini 6 Pack                 301
# ...                                    ...                 ...
# 21438615  Bacardi Multi-Flavor Mini 6 Pack                 301
# 21439949  Bacardi Multi-Flavor Mini 6 Pack                 301
# 21445564  Bacardi Multi-Flavor Mini 6 Pack                 301
# 22147102  Bacardi Multi-Flavor Mini 6 Pack                 301
# 22189771  Bacardi Multi-Flavor Mini 6 Pack                 301
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 42549                  3.33                  5.0            10
# 131187                 3.33                  5.0            20
# 137107                 3.33                  5.0             1
# 397583                 3.33                  5.0            20
# 454710                 3.33                  5.0            20
# ...                     ...                  ...           ...
# 21438615               3.33                  5.0             2
# 21439949               3.33                  5.0             1
# 21445564               3.33                  5.0             2
# 22147102               3.33                  5.0            20
# 22189771               3.33                  5.0            20
#
#           Sale (Dollars)  Volume Sold (Liters)                    Store Name  \
# 42549               50.0                  3.01              Shamrock spirits
# 131187             100.0                  6.02   Hy-vee food store / altoona
# 137107               5.0                  0.30   Hy-vee food store / altoona
# 397583             100.0                  6.02   Hy-vee food store #1 / ames
# 454710             100.0                  6.02               Cyclone liquors
# ...                  ...                   ...                           ...
# 21438615            10.0                  0.60  Slagle's grocery / le claire
# 21439949             5.0                  0.30  Slagle's grocery / le claire
# 21445564            10.0                  0.60  Slagle's grocery / le claire
# 22147102           100.0                  6.02    Hy-vee wine and spirits #2
# 22189771           100.0                  6.02               Ram liquor mart
#
#               Category Name   Category      Vendor Name
# 42549     SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 131187    SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 137107    SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 397583    SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 454710    SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# ...                     ...        ...              ...
# 21438615  SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 21439949  SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 21445564  SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 22147102  SPECIAL PACKAGING  1701200.0  BACARDI USA INC
# 22189771  SPECIAL PACKAGING  1701200.0  BACARDI USA INC
#
# [130 rows x 16 columns]

# %%
# quick swap from 301 to 300
iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(301, 300)

# %%
# Now all the bottle sizes should be correct
iowa['Bottle Volume (ml)'].value_counts()
# Out:
# 750       10249808
# 1750       4533531
# 1000       2904417
# 375        2316718
# 200         811182
# 500         722400
# 50          648301
# 600         218660
# 100         149335
# 3000         94403
# 300          93576
# 800          21644
# 1200         19490
# 2400          7904
# 850           3192
# 400           2214
# 1850          1883
# 1800          1760
# 20            1582
# 900           1481
# 6000          1290
# 3500          1122
# 950            864
# 250            858
# 150            790
# 2250           663
# 1950           566
# 4800           476
# 1125           411
# 502            349
# 25             252
# 603            201
# 1500           190
# 5250           178
# 3600           161
# 4500            79
# 1420            63
# 2550            42
# 175             39
# 425             26
# 378000          24
# 31500           24
# 2000            23
# 2125            16
# 3900            15
# 140000           8
# 355              7
# 180000           2
# 189000           2
# 225000           1
# Name: Bottle Volume (ml), dtype: int64

# %%
# two more! 603, 502
# Bottle volume: 603
iowa[iowa['Bottle Volume (ml)'] == 603]
# Out:
#                Date       City  Zip Code County  Item Number  \
# 137508   2015-09-17    ALTOONA     50009   POLK        65121
# 170690   2016-03-16    ALTOONA     50009   POLK        65121
# 415695   2015-08-12       AMES     50010  STORY        65121
# 421909   2015-08-26       AMES     50010  STORY        65121
# 512730   2015-10-21       AMES     50010  STORY        65121
# ...             ...        ...       ...    ...          ...
# 22591514 2015-08-05  DAVENPORT     52807  SCOTT        65121
# 22601856 2015-10-14  DAVENPORT     52807  SCOTT        65121
# 22648332 2015-10-07  DAVENPORT     52807  SCOTT        65121
# 22709951 2015-12-29  DAVENPORT     52807  SCOTT        65121
# 22712951 2016-02-10  DAVENPORT     52807  SCOTT        65121
#
#                          Item Description  Bottle Volume (ml)  \
# 137508    Grand Marnier Cordon Rouge Mini                 603
# 170690    Grand Marnier Cordon Rouge Mini                 603
# 415695    Grand Marnier Cordon Rouge Mini                 603
# 421909    Grand Marnier Cordon Rouge Mini                 603
# 512730    Grand Marnier Cordon Rouge Mini                 603
# ...                                   ...                 ...
# 22591514  Grand Marnier Cordon Rouge Mini                 603
# 22601856  Grand Marnier Cordon Rouge Mini                 603
# 22648332  Grand Marnier Cordon Rouge Mini                 603
# 22709951  Grand Marnier Cordon Rouge Mini                 603
# 22712951  Grand Marnier Cordon Rouge Mini                 603
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 137508                22.68                34.02             1
# 170690                22.68                34.02            20
# 415695                22.68                34.02             1
# 421909                22.68                34.02             1
# 512730                22.68                34.02             1
# ...                     ...                  ...           ...
# 22591514              22.68                34.02             1
# 22601856              22.68                34.02             1
# 22648332              22.68                34.02             1
# 22709951              22.68                34.02             1
# 22712951              22.68                34.02             1
#
#           Sale (Dollars)  Volume Sold (Liters)                     Store Name  \
# 137508             34.02                  0.60         Super stop 2 / altoona
# 170690            680.40                 12.06  Fareway stores #925 / altoona
# 415695             34.02                  0.60     Hy-vee drugstore #2 / ames
# 421909             34.02                  0.60              Hy-vee  #2 / ames
# 512730             34.02                  0.60              Hy-vee  #2 / ames
# ...                  ...                   ...                            ...
# 22591514           34.02                  0.60   Hy-vee #3 food and drugstore
# 22601856           34.02                  0.60   Hy-vee #3 food and drugstore
# 22648332           34.02                  0.60   Hy-vee #3 food and drugstore
# 22709951           34.02                  0.60   Hy-vee #3 food and drugstore
# 22712951           34.02                  0.60   Hy-vee #3 food and drugstore
#
#          Category Name   Category              Vendor Name
# 137508         LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 170690         LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 415695         LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 421909         LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 512730         LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# ...                ...        ...                      ...
# 22591514       LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 22601856       LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 22648332       LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 22709951       LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
# 22712951       LIQUEUR  1082900.0  MOET HENNESSY USA, INC.
#
# [201 rows x 16 columns]

# %% [markdown]
# #### 603 that looks right

# %%
# Bottle volume: 502
iowa[iowa['Bottle Volume (ml)'] == 502]
# Out:
#                Date       City  Zip Code County  Item Number  \
# 141228   2012-04-26    ALTOONA     50009   POLK        42310
# 142676   2012-04-12    ALTOONA     50009   POLK        42310
# 819059   2012-06-14       AMES     50014  STORY        42310
# 831071   2012-03-29       AMES     50014  STORY        42310
# 959933   2012-09-12     ANKENY     50021   POLK        42310
# ...             ...        ...       ...    ...          ...
# 22638603 2012-04-03  DAVENPORT     52807  SCOTT        42310
# 22645302 2012-08-07  DAVENPORT     52807  SCOTT        42310
# 22650351 2012-09-18  DAVENPORT     52807  SCOTT        42310
# 22667910 2012-06-05  DAVENPORT     52807  SCOTT        42310
# 22685477 2012-04-17  DAVENPORT     52807  SCOTT        42310
#
#              Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 141228    Malibu Red PET Mini                 502                3.3
# 142676    Malibu Red PET Mini                 502                3.3
# 819059    Malibu Red PET Mini                 502                3.3
# 831071    Malibu Red PET Mini                 502                3.3
# 959933    Malibu Red PET Mini                 502                3.3
# ...                       ...                 ...                ...
# 22638603  Malibu Red PET Mini                 502                3.3
# 22645302  Malibu Red PET Mini                 502                3.3
# 22650351  Malibu Red PET Mini                 502                3.3
# 22667910  Malibu Red PET Mini                 502                3.3
# 22685477  Malibu Red PET Mini                 502                3.3
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 141228                   4.95            24          118.80
# 142676                   4.95            12           59.40
# 819059                   4.95             2            9.90
# 831071                   4.95             1            4.95
# 959933                   4.95             1            4.95
# ...                       ...           ...             ...
# 22638603                 4.95             1            4.95
# 22645302                 4.95             1            4.95
# 22650351                 4.95             3           14.85
# 22667910                 4.95             3           14.85
# 22685477                 4.95             3           14.85
#
#           Volume Sold (Liters)                    Store Name Category Name  \
# 141228                   12.05   Hy-vee food store / altoona           RUM
# 142676                    6.02   Hy-vee food store / altoona           RUM
# 819059                    1.00            Aj's liquor / ames           RUM
# 831071                    0.50            Aj's liquor / ames           RUM
# 959933                    0.50     Hy-vee drugstore / ankeny           RUM
# ...                        ...                           ...           ...
# 22638603                  0.50  Hy-vee #3 food and drugstore           RUM
# 22645302                  0.50  Hy-vee #3 food and drugstore           RUM
# 22650351                  1.51  Hy-vee #3 food and drugstore           RUM
# 22667910                  1.51  Hy-vee #3 food and drugstore           RUM
# 22685477                  1.51  Hy-vee #3 food and drugstore           RUM
#
#            Category                       Vendor Name
# 141228    1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 142676    1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 819059    1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 831071    1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 959933    1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# ...             ...                               ...
# 22638603  1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 22645302  1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 22650351  1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 22667910  1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
# 22685477  1062400.0  PERNOD RICARD USA/AUSTIN NICHOLS
#
# [349 rows x 16 columns]

# %%
# 502 is supposed to be 5cl
iowa['Bottle Volume (ml)'] = iowa['Bottle Volume (ml)'].replace(502, 50)

# %% [markdown]
# ## State Bottle Retail

# %%
## state bottle retail
iowa['State Bottle Retail'].describe()
# Out:
# count    2.281221e+07
# mean     1.521282e+01
# std      1.617233e+01
# min      2.900000e-01
# 25%      8.270000e+00
# 50%      1.238000e+01
# 75%      1.874000e+01
# max      1.152000e+04
# Name: State Bottle Retail, dtype: float64

# %% [markdown]
# ### Observations
# 1. There is no zero's
#
# ### Thoughts
# The way I have to check for errors are if retail is less than cost, however things can be sold at a loss.

# %%
# How many times were items sold for a loss?
iowa[iowa['State Bottle Retail'] < iowa['State Bottle Cost']]
# Out:
#                Date          City  Zip Code     County  Item Number  \
# 456653   2012-02-16          AMES     50010      STORY        35109
# 459762   2012-02-02          AMES     50010      STORY        35109
# 535443   2012-02-09          AMES     50010      STORY        35109
# 1587503  2019-12-13      CARLISLE     50047     WARREN          647
# 1587877  2020-12-04      CARLISLE     50047     WARREN        12865
# ...             ...           ...       ...        ...          ...
# 19099579 2012-02-02  CEDAR RAPIDS     52405       LINN        35109
# 19860559 2012-02-15     OSKALOOSA     52577   BUCHANAN        35109
# 20291426 2019-11-06  FORT MADISON     52627        LEE       100762
# 20869124 2012-02-14    BETTENDORF     52722      SCOTT        35109
# 21553042 2012-02-28     MUSCATINE     52761  MUSCATINE        35109
#
#                          Item Description  Bottle Volume (ml)  \
# 456653    Russian Standard Original Vodka                 750
# 459762    Russian Standard Original Vodka                 750
# 535443    Russian Standard Original Vodka                 750
# 1587503     Kahlua w/Absolut 50ml & Glass                 800
# 1587877            Rich & Rare Apple Mini                  50
# ...                                   ...                 ...
# 19099579  Russian Standard Original Vodka                 750
# 19860559  Russian Standard Original Vodka                 750
# 20291426         Bird Dog Peach w/2-50mls                 850
# 20869124  Russian Standard Original Vodka                 750
# 21553042  Russian Standard Original Vodka                 750
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 456653                16.33                14.83             2
# 459762                16.33                14.83             4
# 535443                16.33                14.83             2
# 1587503               10.99                 7.50             6
# 1587877               60.00                 7.74             1
# ...                     ...                  ...           ...
# 19099579              16.33                14.83             2
# 19860559              16.33                14.83             2
# 20291426              10.00                 9.00             6
# 20869124              16.33                14.83             2
# 21553042              16.33                14.83             2
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 456653             29.66                  1.50
# 459762             59.32                  3.00
# 535443             29.66                  1.50
# 1587503            98.94                  4.80
# 1587877             9.00                  0.05
# ...                  ...                   ...
# 19099579           29.66                  1.50
# 19860559           29.66                  1.50
# 20291426           90.00                  5.10
# 20869124           29.66                  1.50
# 21553042           29.66                  1.50
#
#                                     Store Name      Category Name   Category  \
# 456653                       Hy-vee  #2 / ames              VODKA  1032230.0
# 459762                       Hy-vee  #2 / ames              VODKA  1032230.0
# 535443                       Hy-vee  #2 / ames              VODKA  1032230.0
# 1587503         Fareway stores #147 / carlisle  SPECIAL PACKAGING  1701200.0
# 1587877         Fareway stores #147 / carlisle    CANADIAN WHISKY  1012100.0
# ...                                        ...                ...        ...
# 19099579   Hy-vee food store #1 / cedar rapids              VODKA  1032230.0
# 19860559                            C b liquor              VODKA  1032230.0
# 20291426                  Quicker liquor store  SPECIAL PACKAGING  1701200.0
# 20869124  Hy-vee wine and spirits / bettendorf              VODKA  1032230.0
# 21553042         Hy-vee food store / muscatine              VODKA  1032230.0
#
#                                Vendor Name
# 456653         RUSSIAN STANDARD VODKA, USA
# 459762         RUSSIAN STANDARD VODKA, USA
# 535443         RUSSIAN STANDARD VODKA, USA
# 1587503   PERNOD RICARD USA/AUSTIN NICHOLS
# 1587877               SAZERAC COMPANY  INC
# ...                                    ...
# 19099579       RUSSIAN STANDARD VODKA, USA
# 19860559       RUSSIAN STANDARD VODKA, USA
# 20291426  WESTERN SPIRITS BEVERAGE CO. LLC
# 20869124       RUSSIAN STANDARD VODKA, USA
# 21553042       RUSSIAN STANDARD VODKA, USA
#
# [70 rows x 16 columns]

# %%
# some deeper filtering
iowa[(iowa['State Bottle Retail'] < iowa['State Bottle Cost']) & (iowa['Item Description'] != 'Russian Standard Original Vodka')]
# Out:
#                Date             City  Zip Code         County  \
# 1585794  2019-12-13         CARLISLE     50047         WARREN
# 1586167  2020-12-04         CARLISLE     50047         WARREN
# 2431210  2020-12-03         JOHNSTON     50131           POLK
# 2818905  2019-12-17     MARSHALLTOWN     50158       MARSHALL
# 2937011  2020-12-04        MONTEZUMA     50171      POWESHIEK
# 3141897  2019-11-12           NEWTON     50208         JASPER
# 3445239  2019-12-13            PERRY     50220         DALLAS
# 3982488  2019-11-06  WEST DES MOINES     50265           POLK
# 4005733  2021-02-11  WEST DES MOINES     50265           POLK
# 5390543  2021-02-03       DES MOINES     50314           POLK
# 5396529  2021-03-08       DES MOINES     50314           POLK
# 5665156  2021-01-07       DES MOINES     50315           POLK
# 6633904  2019-12-19       DES MOINES     50322           POLK
# 7288810  2021-05-13       MASON CITY     50401    CERRO GORDO
# 7524685  2021-01-07        CLEARLAKE     50428    CERRO GORDO
# 8173913  2019-12-04           ALGONA     50511        KOSSUTH
# 8177156  2021-01-27           ALGONA     50511        KOSSUTH
# 8353278  2021-02-17       EMMETSBURG     50536      PALO ALTO
# 8706831  2021-01-04       STORM LAKE     50588    BUENA VISTA
# 9183859  2020-12-10      CEDAR FALLS     50613     BLACK HAWK
# 9677579  2019-11-05      NEW HAMPTON     50659      CHICKASAW
# 10154383 2019-10-29           NEWTON     50702        WEBSTER
# 10345545 2019-11-19         WATERLOO     50702     BLACK HAWK
# 10347506 2019-12-03         WATERLOO     50702     BLACK HAWK
# 10866581 2019-11-29          CORNING     50841          ADAMS
# 10866632 2019-12-13          CORNING     50841          ADAMS
# 11903661 2019-11-19       SIOUX CITY     51106       WOODBURY
# 12138772 2021-02-02             DOON     51235           LYON
# 12230801 2020-12-08      ROCK RAPIDS     51246           LYON
# 12230844 2020-12-15      ROCK RAPIDS     51246           LYON
# 12231403 2021-01-05      ROCK RAPIDS     51246           LYON
# 12231537 2021-01-12      ROCK RAPIDS     51246           LYON
# 12231654 2021-01-19      ROCK RAPIDS     51246           LYON
# 12231740 2021-01-26      ROCK RAPIDS     51246           LYON
# 12232517 2021-03-16      ROCK RAPIDS     51246           LYON
# 12868370 2021-06-30      SPIRIT LAKE     51360      DICKINSON
# 12992011 2021-02-08          CARROLL     51401        CARROLL
# 13484568 2019-10-30   COUNCIL BLUFFS     51501  POTTAWATTAMIE
# 13965322 2020-12-16         GLENWOOD     51534          MILLS
# 14032218 2020-12-01           HARLAN     51537         SHELBY
# 15278489 2021-01-19       MANCHESTER     52087       DELAWARE
# 15693516 2020-12-24          ANAMOSA     52205          JONES
# 15694767 2021-01-15          ANAMOSA     52205          JONES
# 15697207 2021-03-26          ANAMOSA     52205          JONES
# 17729828 2019-11-27       WASHINGTON     52353     WASHINGTON
# 20269928 2019-11-06     FORT MADISON     52627            LEE
#
#               Category Name  Item Number  \
# 1585794   SPECIAL PACKAGING          647
# 1586167     CANADIAN WHISKY        12865
# 2431210     CANADIAN WHISKY        12865
# 2818905   SPECIAL PACKAGING          647
# 2937011     CANADIAN WHISKY        12865
# 3141897   SPECIAL PACKAGING       100762
# 3445239   SPECIAL PACKAGING          647
# 3982488   SPECIAL PACKAGING       100762
# 4005733     CANADIAN WHISKY        12865
# 5390543     CANADIAN WHISKY        12865
# 5396529     CANADIAN WHISKY        12865
# 5665156     CANADIAN WHISKY        12865
# 6633904   SPECIAL PACKAGING          647
# 7288810             TEQUILA       989235
# 7524685     CANADIAN WHISKY        12865
# 8173913   SPECIAL PACKAGING          647
# 8177156     CANADIAN WHISKY        12865
# 8353278     CANADIAN WHISKY        12865
# 8706831     CANADIAN WHISKY        12865
# 9183859     CANADIAN WHISKY        12865
# 9677579   SPECIAL PACKAGING       100762
# 10154383  SPECIAL PACKAGING       100762
# 10345545  SPECIAL PACKAGING          647
# 10347506  SPECIAL PACKAGING          647
# 10866581  SPECIAL PACKAGING          647
# 10866632  SPECIAL PACKAGING          647
# 11903661  SPECIAL PACKAGING          647
# 12138772    CANADIAN WHISKY        12865
# 12230801    CANADIAN WHISKY        12865
# 12230844    CANADIAN WHISKY        12865
# 12231403    CANADIAN WHISKY        12865
# 12231537    CANADIAN WHISKY        12865
# 12231654    CANADIAN WHISKY        12865
# 12231740    CANADIAN WHISKY        12865
# 12232517    CANADIAN WHISKY        12865
# 12868370      COCKTAILS RTD        62422
# 12992011    CANADIAN WHISKY        12865
# 13484568  SPECIAL PACKAGING       100762
# 13965322    CANADIAN WHISKY        12865
# 14032218    CANADIAN WHISKY        12865
# 15278489    CANADIAN WHISKY        12865
# 15693516    CANADIAN WHISKY        12865
# 15694767    CANADIAN WHISKY        12865
# 15697207    CANADIAN WHISKY        12865
# 17729828  SPECIAL PACKAGING       100762
# 20269928  SPECIAL PACKAGING       100762
#
#                                       Item Description  Bottle Volume (ml)  \
# 1585794                  Kahlua w/Absolut 50ml & Glass                 800
# 1586167                         Rich & Rare Apple Mini                  50
# 2431210                         Rich & Rare Apple Mini                  50
# 2818905                  Kahlua w/Absolut 50ml & Glass                 800
# 2937011                         Rich & Rare Apple Mini                  50
# 3141897                       Bird Dog Peach w/2-50mls                 850
# 3445239                  Kahlua w/Absolut 50ml & Glass                 800
# 3982488                       Bird Dog Peach w/2-50mls                 850
# 4005733                         Rich & Rare Apple Mini                  50
# 5390543                         Rich & Rare Apple Mini                  50
# 5396529                         Rich & Rare Apple Mini                  50
# 5665156                         Rich & Rare Apple Mini                  50
# 6633904                  Kahlua w/Absolut 50ml & Glass                 800
# 7288810                Corazon Reposado Buy the Barrel                 750
# 7524685                         Rich & Rare Apple Mini                  50
# 8173913                  Kahlua w/Absolut 50ml & Glass                 800
# 8177156                         Rich & Rare Apple Mini                  50
# 8353278                         Rich & Rare Apple Mini                  50
# 8706831                         Rich & Rare Apple Mini                  50
# 9183859                         Rich & Rare Apple Mini                  50
# 9677579                       Bird Dog Peach w/2-50mls                 850
# 10154383                      Bird Dog Peach w/2-50mls                 850
# 10345545                 Kahlua w/Absolut 50ml & Glass                 800
# 10347506                 Kahlua w/Absolut 50ml & Glass                 800
# 10866581                 Kahlua w/Absolut 50ml & Glass                 800
# 10866632                 Kahlua w/Absolut 50ml & Glass                 800
# 11903661                 Kahlua w/Absolut 50ml & Glass                 800
# 12138772                        Rich & Rare Apple Mini                  50
# 12230801                        Rich & Rare Apple Mini                  50
# 12230844                        Rich & Rare Apple Mini                  50
# 12231403                        Rich & Rare Apple Mini                  50
# 12231537                        Rich & Rare Apple Mini                  50
# 12231654                        Rich & Rare Apple Mini                  50
# 12231740                        Rich & Rare Apple Mini                  50
# 12232517                        Rich & Rare Apple Mini                  50
# 12868370  Margaritaville Skinny Island Punch Margarita                1750
# 12992011                        Rich & Rare Apple Mini                  50
# 13484568                      Bird Dog Peach w/2-50mls                 850
# 13965322                        Rich & Rare Apple Mini                  50
# 14032218                        Rich & Rare Apple Mini                  50
# 15278489                        Rich & Rare Apple Mini                  50
# 15693516                        Rich & Rare Apple Mini                  50
# 15694767                        Rich & Rare Apple Mini                  50
# 15697207                        Rich & Rare Apple Mini                  50
# 17729828                      Bird Dog Peach w/2-50mls                 850
# 20269928                      Bird Dog Peach w/2-50mls                 850
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 1585794               10.99                 7.50             6
# 1586167               60.00                 7.74             1
# 2431210               60.00                 7.74             3
# 2818905               10.99                 9.74             6
# 2937011               60.00                 7.74             1
# 3141897               10.00                 8.31             6
# 3445239               10.99                10.67             6
# 3982488               10.00                 6.00             6
# 4005733               60.00                 7.74            20
# 5390543               60.00                 7.74            10
# 5396529               60.00                 7.74            10
# 5665156               60.00                 7.74            40
# 6633904               10.99                 9.75             6
# 7288810              262.46                20.63            12
# 7524685               60.00                 7.74            10
# 8173913               10.99                 7.85             6
# 8177156               60.00                 7.74             2
# 8353278               60.00                 7.74             1
# 8706831               60.00                 7.74             1
# 9183859               60.00                 7.74             2
# 9677579               10.00                 7.50             6
# 10154383              10.00                 7.50             6
# 10345545              10.99                 7.50             6
# 10347506              10.99                 9.00             6
# 10866581              10.99                10.80             6
# 10866632              10.99                10.80             6
# 11903661              10.99                 9.00             6
# 12138772              60.00                 7.74            10
# 12230801              60.00                 7.74             1
# 12230844              60.00                 7.74             1
# 12231403              60.00                 7.74             1
# 12231537              60.00                 7.74             1
# 12231654              60.00                 7.74             1
# 12231740              60.00                 7.74             1
# 12232517              60.00                 7.74             1
# 12868370              25.00                10.53             6
# 12992011              60.00                 7.74            10
# 13484568              10.00                 6.71             6
# 13965322              60.00                 7.74             3
# 14032218              60.00                 7.74             2
# 15278489              60.00                 7.74             1
# 15693516              60.00                 7.74             1
# 15694767              60.00                 7.74             1
# 15697207              60.00                 7.74             1
# 17729828              10.00                 9.75             6
# 20269928              10.00                 9.00             6
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 1585794            98.94                  4.80
# 1586167             9.00                  0.05
# 2431210            27.00                  0.15
# 2818905            98.94                  4.80
# 2937011             9.00                  0.05
# 3141897            90.00                  5.10
# 3445239            98.94                  4.80
# 3982488            90.00                  5.10
# 4005733           154.80                  1.00
# 5390543            77.40                  0.50
# 5396529            77.40                  0.50
# 5665156           309.60                  2.00
# 6633904            98.94                  4.80
# 7288810           247.56                  9.00
# 7524685            77.40                  0.50
# 8173913            98.94                  4.80
# 8177156            15.48                  0.10
# 8353278             7.74                  0.05
# 8706831             7.74                  0.05
# 9183859            18.00                  0.10
# 9677579            90.00                  5.10
# 10154383           90.00                  5.10
# 10345545           98.94                  4.80
# 10347506           98.94                  4.80
# 10866581           98.94                  4.80
# 10866632           98.94                  4.80
# 11903661           98.94                  4.80
# 12138772           77.40                  0.50
# 12230801            9.00                  0.05
# 12230844            9.00                  0.05
# 12231403            7.74                  0.05
# 12231537            7.74                  0.05
# 12231654            7.74                  0.05
# 12231740            7.74                  0.05
# 12232517            7.74                  0.05
# 12868370           63.18                 10.50
# 12992011           77.40                  0.50
# 13484568           90.00                  5.10
# 13965322           27.00                  0.15
# 14032218           18.00                  0.10
# 15278489            7.74                  0.05
# 15693516            9.00                  0.05
# 15694767            7.74                  0.05
# 15697207            7.74                  0.05
# 17729828           90.00                  5.10
# 20269928           90.00                  5.10
#
#                                     Store Name   Category  \
# 1585794         Fareway stores #147 / carlisle  1701200.0
# 1586167         Fareway stores #147 / carlisle  1012100.0
# 2431210           Hy-vee food store / johnston  1012100.0
# 2818905             Marshall beer wine spirits  1701200.0
# 2937011                          Monte spirits  1012100.0
# 3141897              Pit stop liquors / newton  1701200.0
# 3445239                         Bluejay market  1701200.0
# 3982488                        Hy-vee #4 / wdm  1701200.0
# 4005733      Casey's general store #3098 / wdm  1012100.0
# 5390543              Central city liquor, inc.  1012100.0
# 5396529              Central city liquor, inc.  1012100.0
# 5665156      Hy-vee food store #3 / des moines  1012100.0
# 6633904       Target store t-2041 / des moines  1701200.0
# 7288810      Hy-vee food store #1 / mason city  1022200.0
# 7524685       Fareway stores #705 / clear lake  1012100.0
# 8173913              One stop shop #3 / algona  1701200.0
# 8177156       Hy-vee wine and spirits / algona  1012100.0
# 8353278       Fareway stores #849 / emmetsburg  1012100.0
# 8706831   Hy-vee wine and spirits / storm lake  1012100.0
# 9183859     United wine & liquor / cedar falls  1012100.0
# 9677579      Fareway stores #922 / new hampton  1701200.0
# 10154383              New star mart  /  newton  1701200.0
# 10345545            The snack shack / waterloo  1701200.0
# 10347506        Target store t-1792 / waterloo  1701200.0
# 10866581           Hy-vee food store / corning  1701200.0
# 10866632           Hy-vee food store / corning  1701200.0
# 11903661      Target store t-1800 / sioux city  1701200.0
# 12138772                             R&l foods  1012100.0
# 12230801                                Todd's  1012100.0
# 12230844                                Todd's  1012100.0
# 12231403                                Todd's  1012100.0
# 12231537                                Todd's  1012100.0
# 12231654                                Todd's  1012100.0
# 12231740                                Todd's  1012100.0
# 12232517                                Todd's  1012100.0
# 12868370                  Pronto / spirit lake  1071100.0
# 12992011         Fareway stores #409 / carroll  1012100.0
# 13484568      Tobacco hut #18 / council bluffs  1701200.0
# 13965322          Pony creek liquor / glenwood  1012100.0
# 14032218  Casey's general store #2914 / harlan  1012100.0
# 15278489           Cork 'n bottle / manchester  1012100.0
# 15693516      Giggle juice liquor station, llc  1012100.0
# 15694767      Giggle juice liquor station, llc  1012100.0
# 15697207      Giggle juice liquor station, llc  1012100.0
# 17729828  Hy-vee wine and spirits / washington  1701200.0
# 20269928                  Quicker liquor store  1701200.0
#
#                       Vendor Name
# 1585794         PERNOD RICARD USA
# 1586167                SAZERAC CO
# 2431210                SAZERAC CO
# 2818905         PERNOD RICARD USA
# 2937011                SAZERAC CO
# 3141897   WESTERN SPIRIT BEVERAGE
# 3445239         PERNOD RICARD USA
# 3982488   WESTERN SPIRIT BEVERAGE
# 4005733                SAZERAC CO
# 5390543                SAZERAC CO
# 5396529                SAZERAC CO
# 5665156                SAZERAC CO
# 6633904         PERNOD RICARD USA
# 7288810             GEMINI SPIRIT
# 7524685                SAZERAC CO
# 8173913         PERNOD RICARD USA
# 8177156                SAZERAC CO
# 8353278                SAZERAC CO
# 8706831                SAZERAC CO
# 9183859                SAZERAC CO
# 9677579   WESTERN SPIRIT BEVERAGE
# 10154383  WESTERN SPIRIT BEVERAGE
# 10345545        PERNOD RICARD USA
# 10347506        PERNOD RICARD USA
# 10866581        PERNOD RICARD USA
# 10866632        PERNOD RICARD USA
# 11903661        PERNOD RICARD USA
# 12138772               SAZERAC CO
# 12230801               SAZERAC CO
# 12230844               SAZERAC CO
# 12231403               SAZERAC CO
# 12231537               SAZERAC CO
# 12231654               SAZERAC CO
# 12231740               SAZERAC CO
# 12232517               SAZERAC CO
# 12868370            GEMINI SPIRIT
# 12992011               SAZERAC CO
# 13484568  WESTERN SPIRIT BEVERAGE
# 13965322               SAZERAC CO
# 14032218               SAZERAC CO
# 15278489               SAZERAC CO
# 15693516               SAZERAC CO
# 15694767               SAZERAC CO
# 15697207               SAZERAC CO
# 17729828  WESTERN SPIRIT BEVERAGE
# 20269928  WESTERN SPIRIT BEVERAGE

# %% [markdown]
# ### Observations
# 1. The products left over some bird dog peach which definitely has the wrong sales amount,but that will be fixed later
# 2. Rich & Rare Apple Mini can't be $60
# 3. Corazon Reposado Buy the Barrel has a cost of 262.46 and a sale of 20.63
# 4. the kahlua / vodka kit seems to also have incorrect sale prices
# 5. they are all 98.94 for 6 packs but the retail price changes by invoice
# 6. it seems like these promotional packaged booze lose money

# %%
# I don't really know the R & R mini should be costed at. a google search says in texas they go for $1.09
# which is much less than the $7.74
iowa[iowa['Item Description'] == 'Rich & Rare Apple Mini']
# Out:
#                Date       City  Zip Code County  Item Number  \
# 61263    2016-11-16    ALTOONA     50009   POLK        12865
# 184358   2021-11-11    ALTOONA     50009   POLK        12865
# 192364   2021-12-23    ALTOONA     50009   POLK        12865
# 232542   2016-05-25    ALTOONA     50009   POLK        12865
# 293041   2017-01-18       AMES     50010  STORY        12865
# ...             ...        ...       ...    ...          ...
# 22082864 2017-03-08  DAVENPORT     52804  SCOTT        12865
# 22114007 2018-04-04  DAVENPORT     52804  SCOTT        12865
# 22291160 2021-10-26  DAVENPORT     52804  SCOTT        12865
# 22348696 2017-03-16  DAVENPORT     52806  SCOTT        12865
# 22474745 2021-06-23  DAVENPORT     52806  SCOTT        12865
#
#                 Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 61263     Rich & Rare Apple Mini                 600               6.00
# 184358    Rich & Rare Apple Mini                  50               5.16
# 192364    Rich & Rare Apple Mini                  50               5.16
# 232542    Rich & Rare Apple Mini                 600               6.00
# 293041    Rich & Rare Apple Mini                 600               6.00
# ...                          ...                 ...                ...
# 22082864  Rich & Rare Apple Mini                 600               6.00
# 22114007  Rich & Rare Apple Mini                 600               6.00
# 22291160  Rich & Rare Apple Mini                  50               5.16
# 22348696  Rich & Rare Apple Mini                 600               6.00
# 22474745  Rich & Rare Apple Mini                  50               5.16
#
#           State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 61263                    9.00             5           45.00
# 184358                   7.74            10           77.40
# 192364                   7.74             1            7.74
# 232542                   9.00             5           45.00
# 293041                   9.00             5           45.00
# ...                       ...           ...             ...
# 22082864                 9.00             1            9.00
# 22114007                 9.00            10           90.00
# 22291160                 7.74             1            7.74
# 22348696                 9.00             3           27.00
# 22474745                 7.74             2           15.48
#
#           Volume Sold (Liters)                     Store Name  \
# 61263                     3.00  Fareway stores #925 / altoona
# 184358                    0.50    Hy-vee food store / altoona
# 192364                    0.05  Fareway stores #925 / altoona
# 232542                    3.00  Fareway stores #925 / altoona
# 293041                    3.00     Hy-vee drugstore #2 / ames
# ...                        ...                            ...
# 22082864                  0.60     Hy-vee wine and spirits #2
# 22114007                  6.00                 Famous liquors
# 22291160                  0.05          Hy-vee #5 / davenport
# 22348696                  1.80            The liquor stop llc
# 22474745                  0.10            The liquor stop llc
#
#             Category Name   Category           Vendor Name
# 61263     CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 184358    CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 192364    CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 232542    CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 293041    CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# ...                   ...        ...                   ...
# 22082864  CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 22114007  CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 22291160  CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 22348696  CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
# 22474745  CANADIAN WHISKY  1012100.0  SAZERAC COMPANY  INC
#
# [491 rows x 16 columns]

# %%
# it would appear $5.16 is the correct answer. 

iowa[(iowa['State Bottle Cost'] == 60.00) & (iowa['Item Description'] == 'Rich & Rare Apple Mini')] = iowa[(iowa['State Bottle Cost'] == 60.00) & (iowa['Item Description'] == 'Rich & Rare Apple Mini')].replace(60.0,5.16)

# %%
# 'Corazon Reposado Buy the Barrel'
iowa[iowa['Item Description'] == 'Corazon Reposado Buy the Barrel']
# Out:
#                Date            City  Zip Code         County  Item Number  \
# 5411033  2021-05-10      DES MOINES     50314           POLK       989235
# 7297173  2021-05-13      MASON CITY     50401    CERRO GORDO       989235
# 8075541  2021-05-14      FORT DODGE     50501        WEBSTER       989235
# 9231477  2021-06-10     CEDAR FALLS     50613     BLACK HAWK       989235
# 11937683 2021-05-13      SIOUX CITY     51106       WOODBURY       989235
# 13833251 2021-05-12  COUNCIL BLUFFS     51503  POTTAWATTAMIE       989235
# 14689257 2021-05-14         DUBUQUE     52001        DUBUQUE       989235
# 17930650 2021-05-10    CEDAR RAPIDS     52401           LINN       989235
# 20433435 2021-05-13          KEOKUK     52632            LEE       989235
# 20913610 2021-05-10      BETTENDORF     52722          SCOTT       989235
# 21313162 2021-05-10          DEWITT     52742        CLINTON       989235
# 21313712 2021-06-02          DEWITT     52742        CLINTON       989235
#
#                          Item Description  Bottle Volume (ml)  \
# 5411033   Corazon Reposado Buy the Barrel                 750
# 7297173   Corazon Reposado Buy the Barrel                 750
# 8075541   Corazon Reposado Buy the Barrel                 750
# 9231477   Corazon Reposado Buy the Barrel                 750
# 11937683  Corazon Reposado Buy the Barrel                 750
# 13833251  Corazon Reposado Buy the Barrel                 750
# 14689257  Corazon Reposado Buy the Barrel                 750
# 17930650  Corazon Reposado Buy the Barrel                 750
# 20433435  Corazon Reposado Buy the Barrel                 750
# 20913610  Corazon Reposado Buy the Barrel                 750
# 21313162  Corazon Reposado Buy the Barrel                 750
# 21313712  Corazon Reposado Buy the Barrel                 750
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 5411033               11.00                20.63            60
# 7297173              262.46                20.63            12
# 8075541                7.47                20.63            12
# 9231477               13.75                20.63             6
# 11937683               9.06                20.63             6
# 13833251              11.07                20.63            12
# 14689257               6.00                20.63            12
# 17930650               5.94                20.63            48
# 20433435              15.33                20.63             6
# 20913610               8.74                20.63            24
# 21313162               6.38                20.63            12
# 21313712              13.75                20.63            18
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 5411033          1237.80                  45.0
# 7297173           247.56                   9.0
# 8075541           247.56                   9.0
# 9231477           123.78                   4.5
# 11937683          123.78                   4.5
# 13833251          247.56                   9.0
# 14689257          247.56                   9.0
# 17930650          990.24                  36.0
# 20433435          123.78                   4.5
# 20913610          495.12                  18.0
# 21313162          247.56                   9.0
# 21313712          371.34                  13.5
#
#                                      Store Name Category Name   Category  \
# 5411033                          Central city 2       TEQUILA  1022200.0
# 7297173       Hy-vee food store #1 / mason city       TEQUILA  1022200.0
# 8075541      Hy-vee fort dodge wine and spirits       TEQUILA  1022200.0
# 9231477             Hillstreet news and tobacco       TEQUILA  1022200.0
# 11937683         Hy-vee food store / sioux city       TEQUILA  1022200.0
# 13833251  Hy-vee food store #2 / council bluffs       TEQUILA  1022200.0
# 14689257            Hy-vee food store / dubuque       TEQUILA  1022200.0
# 17930650                      Benz distributing       TEQUILA  1022200.0
# 20433435                         Keokuk spirits       TEQUILA  1022200.0
# 20913610                          Lot-a-spirits       TEQUILA  1022200.0
# 21313162                 Another round / dewitt       TEQUILA  1022200.0
# 21313712                 Another round / dewitt       TEQUILA  1022200.0
#
#                    Vendor Name
# 5411033         GEMINI SPIRITS
# 7297173         GEMINI SPIRITS
# 8075541         GEMINI SPIRITS
# 9231477   SAZERAC COMPANY  INC
# 11937683        GEMINI SPIRITS
# 13833251        GEMINI SPIRITS
# 14689257        GEMINI SPIRITS
# 17930650        GEMINI SPIRITS
# 20433435        GEMINI SPIRITS
# 20913610        GEMINI SPIRITS
# 21313162        GEMINI SPIRITS
# 21313712  SAZERAC COMPANY  INC

# %% [markdown]
# ### Interesting result.
# the bottle cost for 'Corazon Reposado Buy the Barrel' is all over the place, however mostly great returns
# I am going to replace the 262... with a value from the same invoice date

# %%
iowa[(iowa['State Bottle Cost'] == 262.46) & (iowa['Item Description'] == 'Corazon Reposado Buy the Barrel')] = iowa[(iowa['State Bottle Cost'] == 262.46) & (iowa['Item Description'] == 'Corazon Reposado Buy the Barrel')].replace(262.46, 15.33)

# %% [markdown]
# ## BOTTLE SOLD

# %%
iowa['Bottles Sold'].value_counts()
# Out:
# 12      6037635
# 6       4601786
# 2       3011982
# 1       2548857
# 3       2256427
#          ...
# 469           1
# 2352          1
# 538           1
# 337           1
# 193           1
# Name: Bottles Sold, Length: 652, dtype: int64

# %%
iowa[iowa['Bottles Sold'] == 0]
# Out:
#                Date             City  Zip Code       County  Item Number  \
# 1743524  2018-06-05           GRIMES     50111         POLK         5153
# 2051601  2017-10-31        INDIANOLA     50125       WARREN        16416
# 3399453  2016-08-31            PELLA     50219       MARION        44217
# 4108869  2016-10-06  WEST DES MOINES     50266       DALLAS       987514
# 8756845  2016-08-30       STORM LAKE     50588  BUENA VISTA        69636
# 10679449 2016-08-30         WATERLOO     50703   BLACK HAWK        86673
# 21421024 2017-04-12        LE CLAIRE     52753        SCOTT        76658
# 21740745 2016-08-29        MUSCATINE     52761    MUSCATINE        35109
#
#                                  Item Description  Bottle Volume (ml)  \
# 1743524                Glenlivet Founders Reserve                 750
# 2051601   Old Grand-Dad 100 Prf Bond Bourbon 4 Yr                 750
# 3399453                          Barton Rum Light                1000
# 4108869           Kirkland Signature French Vodka                1750
# 8756845        Dr. Mcgillicuddy's Cherry Schnapps                 750
# 10679449            Jack Daniel's Tennessee Honey                1750
# 21421024                   Pear Necessity Liqueur                 375
# 21740745                         Russian Standard                 750
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 1743524               19.98                29.97             0
# 2051601               13.12                19.68             0
# 3399453                4.00                 6.00             0
# 4108869               15.12                22.68             0
# 8756845                8.66                12.99             0
# 10679449              30.68                46.02             0
# 21421024               9.00                13.50             0
# 21740745              10.00                15.00             0
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 1743524           359.64                  0.06
# 2051601           236.16                  0.68
# 3399453            72.00                  0.50
# 4108869             0.00                  0.21
# 8756845           155.88                  0.06
# 10679449          276.12                  0.29
# 21421024          162.00                  0.03
# 21740745          180.00                  0.56
#
#                                        Store Name Category Name   Category  \
# 1743524   Southern glazers wine & spirits of iowa        WHISKY  1012400.0
# 2051601                  Indy 66 #928 / indianola    RYE WHISKY  1081500.0
# 3399453           Hy-vee wine and spirits / pella           RUM  1062400.0
# 4108869               Costco wholesale #788 / wdm         VODKA  1032230.0
# 8756845      Hy-vee wine and spirits / storm lake      SCHNAPPS  1082390.0
# 10679449           Prime mart / broadway waterloo        WHISKY  1012400.0
# 21421024          Mississippi river distilling co      SCHNAPPS  1082390.0
# 21740745            Hy-vee food store / muscatine         VODKA  1032230.0
#
#                                Vendor Name
# 1743524   PERNOD RICARD USA/AUSTIN NICHOLS
# 2051601                    JIM BEAM BRANDS
# 3399453              SAZERAC NORTH AMERICA
# 4108869                   MISA IMPORTS INC
# 8756845               SAZERAC COMPANY  INC
# 10679449          BROWN-FORMAN CORPORATION
# 21421024  MISSISSIPPI RIVER DISTILLING CO.
# 21740745       RUSSIAN STANDARD VODKA, USA

# %% [markdown]
# ### Observations
# 1. multiple errors here when bottles sold are 0
# 2. every bottles sold, appears to be actually 12, this is based on sale dollars and retail sale price.
# 3. the exception is costco vodka. which has no bottles sold and no sale price. I might have to delete that entry

# %%
# exploring costco
iowa[iowa['Item Description'] == 'Kirkland Signature French Vodka']
# Out:
#                Date             City  Zip Code  County  Item Number  \
# 4108595  2018-10-04  WEST DES MOINES     50266  DALLAS       987514
# 4108869  2016-10-06  WEST DES MOINES     50266  DALLAS       987514
# 4114370  2018-12-13  WEST DES MOINES     50266  DALLAS       987514
# 4117365  2019-01-24  WEST DES MOINES     50266  DALLAS       987514
# 4120565  2018-08-02  WEST DES MOINES     50266  DALLAS       987514
# ...             ...              ...       ...     ...          ...
# 22765165 2021-09-28        DAVENPORT     52807   SCOTT       987514
# 22773311 2020-11-03        DAVENPORT     52807   SCOTT       987514
# 22780545 2020-11-17        DAVENPORT     52807   SCOTT       987514
# 22791790 2020-06-09        DAVENPORT     52807   SCOTT       987514
# 22795905 2020-09-22        DAVENPORT     52807   SCOTT       987514
#
#                          Item Description  Bottle Volume (ml)  \
# 4108595   Kirkland Signature French Vodka                1750
# 4108869   Kirkland Signature French Vodka                1750
# 4114370   Kirkland Signature French Vodka                1750
# 4117365   Kirkland Signature French Vodka                1750
# 4120565   Kirkland Signature French Vodka                1750
# ...                                   ...                 ...
# 22765165  Kirkland Signature French Vodka                1750
# 22773311  Kirkland Signature French Vodka                1750
# 22780545  Kirkland Signature French Vodka                1750
# 22791790  Kirkland Signature French Vodka                1750
# 22795905  Kirkland Signature French Vodka                1750
#
#           State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 4108595               14.48                21.72           576
# 4108869               15.12                22.68             0
# 4114370               14.48                21.72           288
# 4117365               14.48                21.72          1728
# 4120565               14.48                21.72          2010
# ...                     ...                  ...           ...
# 22765165              11.69                17.54           612
# 22773311              14.47                21.71           576
# 22780545              14.47                21.71           288
# 22791790              14.47                21.71           288
# 22795905              14.47                21.71           576
#
#           Sale (Dollars)  Volume Sold (Liters)  \
# 4108595         12510.72               1008.00
# 4108869             0.00                  0.21
# 4114370          6255.36                504.00
# 4117365         37532.16               3024.00
# 4120565         43657.20               3517.50
# ...                  ...                   ...
# 22765165        10734.48               1071.00
# 22773311        12504.96               1008.00
# 22780545         6252.48                504.00
# 22791790         6252.48                504.00
# 22795905        12504.96               1008.00
#
#                                   Store Name Category Name   Category  \
# 4108595          Costco wholesale #788 / wdm         VODKA  1032230.0
# 4108869          Costco wholesale #788 / wdm         VODKA  1032230.0
# 4114370          Costco wholesale #788 / wdm         VODKA  1032230.0
# 4117365          Costco wholesale #788 / wdm         VODKA  1032230.0
# 4120565          Costco wholesale #788 / wdm         VODKA  1032230.0
# ...                                      ...           ...        ...
# 22765165  Costco wholesale #1325 / davenport         VODKA  1032230.0
# 22773311  Costco wholesale #1325 / davenport         VODKA  1032230.0
# 22780545  Costco wholesale #1325 / davenport         VODKA  1032230.0
# 22791790  Costco wholesale #1325 / davenport         VODKA  1032230.0
# 22795905  Costco wholesale #1325 / davenport         VODKA  1032230.0
#
#                Vendor Name
# 4108595   MISA IMPORTS INC
# 4108869   MISA IMPORTS INC
# 4114370   MISA IMPORTS INC
# 4117365   MISA IMPORTS INC
# 4120565   MISA IMPORTS INC
# ...                    ...
# 22765165  MISA IMPORTS INC
# 22773311  MISA IMPORTS INC
# 22780545  MISA IMPORTS INC
# 22791790  MISA IMPORTS INC
# 22795905  MISA IMPORTS INC
#
# [97 rows x 16 columns]

# %%
## I am going to delete that entry because Costco buys so much vodka at once that I can not possibly predict
# the correct value
iowa[(iowa['Item Description'] == 'Kirkland Signature French Vodka') & (iowa['Bottles Sold'] == 0)]
# Out:
#               Date             City  Zip Code  County  Item Number  \
# 4108869 2016-10-06  WEST DES MOINES     50266  DALLAS       987514
#
#                         Item Description  Bottle Volume (ml)  \
# 4108869  Kirkland Signature French Vodka                1750
#
#          State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 4108869              15.12                22.68             0             0.0
#
#          Volume Sold (Liters)                   Store Name Category Name  \
# 4108869                  0.21  Costco wholesale #788 / wdm         VODKA
#
#           Category       Vendor Name
# 4108869  1032230.0  MISA IMPORTS INC

# %%
# drop that costco index
iowa = iowa.drop(4104807)

# %%
# now we want to make all these 0's 12's, and it is easy because the only entries with 0's are the bottle sold column
iowa['Bottles Sold'] = iowa['Bottles Sold'].replace(0,12)

# %% [markdown]
# ## Sale (Dollars) and Volume Sold (Liters)

# %%
# These columns contain some errors and will be updated through math. 

# sale is: bottles sold * retail
# volume sold is: bottles sold * (bottle volume/1000)

# 1000 is for unit conversion
iowa['Sale (Dollars)'] = iowa['Bottles Sold'] * iowa['State Bottle Retail']
iowa['Volume Sold (Liters)'] = iowa['Bottles Sold'] * iowa['Bottle Volume (ml)'] / 1000

# %%
iowa.head()
# Out:
#         Date   City  Zip Code County  Item Number  \
# 0 2018-09-24  ADAIR     50002  ADAIR        86691
# 1 2018-09-24  ADAIR     50002  ADAIR        25606
# 2 2018-09-24  ADAIR     50002  ADAIR        37994
# 3 2018-09-24  ADAIR     50002  ADAIR        36304
# 4 2018-09-24  ADAIR     50002  ADAIR        26826
#
#                    Item Description  Bottle Volume (ml)  State Bottle Cost  \
# 0  Jack Daniels Tennessee Fire Mini                 500               9.06
# 1       Seagrams 7 Crown Bl Whiskey                 750               7.00
# 2                    Smirnoff 80prf                 375               4.75
# 3                     Hawkeye Vodka                 375               1.86
# 4     Jack Daniels Old #7 Black Lbl                 750              15.57
#
#    State Bottle Retail  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                13.59             3           40.77                  1.50
# 1                10.50            12          126.00                  9.00
# 2                 7.13             6           42.78                  2.25
# 3                 2.79            24           66.96                  9.00
# 4                23.36            12          280.32                  9.00
#
#                             Store Name Category Name   Category  \
# 0  Casey's general store #2521 / adair        WHISKY  1012400.0
# 1                 Kum & go #76 / adair        WHISKY  1012400.0
# 2  Casey's general store #2521 / adair         VODKA  1032230.0
# 3                 Kum & go #76 / adair         VODKA  1032230.0
# 4                 Kum & go #76 / adair        WHISKY  1012400.0
#
#                 Vendor Name
# 0  BROWN-FORMAN CORPORATION
# 1           DIAGEO AMERICAS
# 2           DIAGEO AMERICAS
# 3            LUXCO-ST LOUIS
# 4  BROWN-FORMAN CORPORATION

# %%
iowa.to_csv('iowa_clean.csv')
