# %% [markdown]
# # Pre Processing Iowa Liquor Database

# %% [markdown]
# 1. Dealing with nan's
# 2. Expand the date column
# 3. One Hot Encoding categorical data
# 3. Rank stores by rtd & mezcal
# 4. Test Train Split
# 5. StandardScaler

# %%
# libraries
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split

pd.set_option("display.max_rows", 99)

# %%
# load data
iowa = pd.read_csv('iowa_eda.csv')

# %%
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4807658 entries, 0 to 4807657
# Data columns (total 23 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Date                      object
#  1   Address                   object
#  2   City                      object
#  3   Zip Code                  int64
#  4   County                    object
#  5   Category Name             object
#  6   Item Number               int64
#  7   Item Description          object
#  8   Bottle Volume (ml)        int64
#  9   State Bottle Cost         float64
#  10  State Bottle Retail       float64
#  11  Bottles Sold              int64
#  12  Sale (Dollars)            float64
#  13  Volume Sold (Liters)      float64
#  14  Store Name                object
#  15  Category                  float64
#  16  Vendor Name               object
#  17  Profit / Item             float64
#  18  Profit / Invoice          float64
#  19  Profit / ml               float64
#  20  Profit / Invoice / Liter  float64
#  21  Retail Price / ml         float64
#  22  Bottle Price Category     object
# dtypes: float64(10), int64(4), object(9)
# memory usage: 843.6+ MB

# %%
iowa.head()
# Out:
#          Date              Address  City  Zip Code  County    Category Name  \
# 0  2018-09-04  804 Nile Kinnick Dr  ADEL     50003  DALLAS            VODKA
# 1  2018-09-04  804 Nile Kinnick Dr  ADEL     50003  DALLAS   BOURBON WHISKY
# 2  2018-09-04  804 Nile Kinnick Dr  ADEL     50003  DALLAS       RYE WHISKY
# 3  2018-09-04  804 Nile Kinnick Dr  ADEL     50003  DALLAS           SCOTCH
# 4  2018-09-04  409 Nile Kinnick Dr  ADEL     50003  DALLAS  FLAVORED WHISKY
#
#    Item Number                          Item Description  Bottle Volume (ml)  \
# 0        34821                              Svedka Vodka                1750
# 1        27408                       Jim Beam Honey Mini                 500
# 2        27025                            Bulleit 95 Rye                 750
# 3        10008                      Scoresby Rare Scotch                1750
# 4        64858  Fireball Cinnamon Whiskey Mini Dispenser                3000
#
#    State Bottle Cost  ...  Volume Sold (Liters)                  Store Name  \
# 0               13.0  ...                 525.0  Fareway stores #124 / adel
# 1                5.4  ...                   6.0  Fareway stores #124 / adel
# 2               16.0  ...                   9.0  Fareway stores #124 / adel
# 3               10.5  ...                  10.5  Fareway stores #124 / adel
# 4               30.0  ...                  12.0       Kum & go #2093 / adel
#
#     Category                       Vendor Name Profit / Item  \
# 0  1032230.0  CONSTELLATION WINE COMPANY, INC.          6.50
# 1  1011500.0                   JIM BEAM BRANDS          2.70
# 2  1081500.0                   DIAGEO AMERICAS          8.00
# 3  1012300.0                   DIAGEO AMERICAS          5.25
# 4  1081600.0              SAZERAC COMPANY  INC         15.00
#
#    Profit / Invoice Profit / ml  Profit / Invoice / Liter  Retail Price / ml  \
# 0            1950.0    0.003714                  3.714286           0.011143
# 1              32.4    0.005400                  5.400000           0.016200
# 2              96.0    0.010667                 10.666667           0.032000
# 3              31.5    0.003000                  3.000000           0.009000
# 4              60.0    0.005000                  5.000000           0.015000
#
#    Bottle Price Category
# 0                 Normal
# 1            Inexpensive
# 2                 Normal
# 3                 Normal
# 4                 Normal
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Preprocessing 1: dealing with nan's

# %%
# dealing with nans
iowa.isna().sum()
# Out:
# Date                           0
# Address                        0
# City                           0
# Zip Code                       0
# County                         0
# Category Name               5726
# Item Number                    0
# Item Description               0
# Bottle Volume (ml)             0
# State Bottle Cost              2
# State Bottle Retail            2
# Bottles Sold                   0
# Sale (Dollars)                 2
# Volume Sold (Liters)           0
# Store Name                     0
# Category                       0
# Vendor Name                    1
# Profit / Item                  2
# Profit / Invoice               2
# Profit / ml                    2
# Profit / Invoice / Liter       2
# Retail Price / ml              2
# Bottle Price Category          0
# dtype: int64

# %% [markdown]
# #### Category will need to be dealt with. The rest are so few they will be dropped.

# %%
# fill category name by grouping them by their category number
iowa['Category Name'] = iowa.groupby('Category')['Category Name'].ffill().bfill()

# %%
iowa.isna().sum()
# Out:
# Date                        0
# Address                     0
# City                        0
# Zip Code                    0
# County                      0
# Category Name               0
# Item Number                 0
# Item Description            0
# Bottle Volume (ml)          0
# State Bottle Cost           2
# State Bottle Retail         2
# Bottles Sold                0
# Sale (Dollars)              2
# Volume Sold (Liters)        0
# Store Name                  0
# Category                    0
# Vendor Name                 1
# Profit / Item               2
# Profit / Invoice            2
# Profit / ml                 2
# Profit / Invoice / Liter    2
# Retail Price / ml           2
# Bottle Price Category       0
# dtype: int64

# %%
# remove the rest
iowa = iowa.dropna()

# %% [markdown]
# ### Pre Processing 2: Expand the Date column

# %%
# create columns for date info
iowa[['Date_year', 'Date_month', 'Date_day']] = iowa['Date'].str.split("-", expand = True)

# %%
# fix the data type. for the new columns because they are strings of numbers
iowa[['Date_year', 'Date_month', 'Date_day']] = iowa[['Date_year', 'Date_month', 'Date_day']].apply(pd.to_numeric)

# %% [markdown]
# ### Pre Processing 3: Rank entries

# %%
ranking
# Out:
#                                          Store Name  Bottles Sold  \
# 0                                    Central city 2          2966
# 1                      Hy-vee #3 / bdi / des moines          2852
# 2                         Central city liquor, inc.          1493
# 3                     Hy-vee food store / urbandale           907
# 4                     Ingersoll liquor and beverage           678
# 5                            Hy-vee # 6/ des moines           484
# 6                   Hy-vee food store / fleur / dsm           389
# 7                            Tequila's liquor store           359
# 8                     Hy-vee wine and spirits / wdm           311
# 9                                   Hy-vee #4 / wdm           276
# 10                                  Hy-vee / waukee           255
# 11              Hy-vee drugstore / university / dsm           251
# 12              Hy-vee food store #2 / state ankeny           237
# 13                         Hy-vee / windsor heights           236
# 14                      Hy-vee food store / altoona           181
# 15                               Whole foods market           140
# 16                Hy-vee food store #3 / des moines           138
# 17                         Ingersoll wine merchants           137
# 18                           Hy-vee / pleasant hill           106
# 19                       Hy-vee food store #1 / wdm           104
# 20               Hy-vee food and drug / grand / wdm            95
# 21                Hy-vee food store #5 / des moines            88
# 22               Super quick mart / windsor heights            86
# 23                         University liquors / wdm            82
# 24  Wall to wall wine and spirits / west des moines            71
# 25                 Hy-vee wine and spirits / ankeny            69
# 26                                 Urbandale liquor            62
# 27                      Price chopper  /  ingersoll            60
# 28                       Hy-vee wine and spirits #1            47
# 29                             Hy-vee store / perry            45
# 30                                  Smoke shop, the            44
# 31                                  Hy-vee / grimes            42
# 32                         Hy-vee wdm health market            42
# 33                                   Lickety liquor            42
# 34                     Hy-vee food store / johnston            42
# 35                Sam's club 6344 / windsor heights            36
# 36                                 Sahota food mart            30
# 37                                   West d liquors            27
# 38                         Rodgers spirits and more            24
# 39                         Sam's club 6979 / ankeny            24
# 40                           World liquor & tobacco            24
# 41                           1st stop beverage shop            24
# 42                            Best food mart 3  llc            24
# 43           World liquor & tobacco + vapors / adel            22
# 44                                            Oasis            20
# 45                                   Bluejay market            20
# 46                                 Polk city liquor            18
# 47                    Hy-vee food store / indianola            18
# 48                        Hy-vee drugstore #2 / wdm            18
# 49                            Allcool liquors / wdm            16
# 50                             South side food mart            14
# 51                 Royal food & liquor / des moines            14
# 52      Blind pig cocktail bodega / west des moines            13
# 53                          Spirits liquor / grimes            13
# 54          Southern glazers wine & spirits of iowa            13
# 55                         First stop beverage shop            12
# 56                                          U s gas            12
# 57                             Cash saver  /  fleur            12
# 58                       Price chopper  /  johnston            12
# 59                                Adventureland inn            10
# 60                          Smoker's genie / waukee             9
# 61                       Southside tobacco & liquor             8
# 62             Super stop liquor and wine / altoona             8
# 63                       The liquor cabinet / clive             7
# 64                     Fareway stores #983 / grimes             7
# 65                            A a and m inc / perry             6
# 66                                    Sa petro mart             6
# 67               Speedee mart 1515 / council bluffs             6
# 68                         Wine and spirits gallery             6
# 69                    Fareway stores #925 / altoona             6
# 70                           Super stop 2 / altoona             6
# 71                        East end liquor & tobacco             5
# 72                          Last stop beverage shop             5
# 73                     East end liquor / des moines             4
# 74                         Brick street market, llc             3
# 75                               Oasis / des moines             3
# 76         World liquor & tobacco + vapors / waukee             3
# 77                     Your private bar / urbandale             3
# 78                                      Phillips 66             3
# 79                           Super quick / se 30 dm             2
# 80                           Johnson brothers wirtz             2
# 81                          Hometown foods / panora             2
# 82                        I towner stop / indianola             2
# 83                                           Easygo             2
# 84                     East side liquor and tobacco             2
# 85                                  Bottle boutique             1
# 86                                    Family pantry             1
#
#     Item Description
# 0                 12
# 1                 27
# 2                 25
# 3                  9
# 4                 13
# 5                 18
# 6                  8
# 7                 18
# 8                  5
# 9                  7
# 10                 3
# 11                 7
# 12                 6
# 13                 5
# 14                 5
# 15                 3
# 16                 3
# 17                10
# 18                10
# 19                 3
# 20                 6
# 21                 5
# 22                 7
# 23                12
# 24                 9
# 25                 6
# 26                 3
# 27                 1
# 28                 5
# 29                 2
# 30                 8
# 31                 3
# 32                 6
# 33                 1
# 34                 3
# 35                 1
# 36                 1
# 37                 3
# 38                 1
# 39                 1
# 40                 4
# 41                 3
# 42                 3
# 43                 5
# 44                 2
# 45                 9
# 46                 3
# 47                 1
# 48                 1
# 49                 1
# 50                 1
# 51                 4
# 52                 3
# 53                 2
# 54                 3
# 55                 1
# 56                 1
# 57                 1
# 58                 1
# 59                 4
# 60                 4
# 61                 1
# 62                 2
# 63                 4
# 64                 1
# 65                 3
# 66                 1
# 67                 2
# 68                 1
# 69                 1
# 70                 4
# 71                 2
# 72                 1
# 73                 1
# 74                 1
# 75                 2
# 76                 1
# 77                 3
# 78                 1
# 79                 1
# 80                 1
# 81                 1
# 82                 1
# 83                 1
# 84                 2
# 85                 1
# 86                 1

# %%
###
# find out which stores carry the most mezcal products
###

# create a df of only the mezcal entries
mezcal = iowa[iowa['Category Name'] == 'MEZCAL']

# take the mezcal entries, group them by store name and order them by highest variety of products
mezcal_bottles = pd.DataFrame(mezcal.groupby('Store Name')['Bottles Sold'].sum().sort_values(ascending=False))

# take the mezcal entries, group them by store name and order them by highest variety of products
mezcal_variety = pd.DataFrame(mezcal.groupby('Store Name')['Item Description'].nunique().sort_values(ascending=False))

# access the grouped columns
mezcal_bottles = mezcal_bottles.reset_index()
mezcal_variety = mezcal_variety.reset_index()

# join the individual tables
ranking = pd.merge(mezcal_bottles, mezcal_variety, on='Store Name')


####
# find out which stores dont carry the mezcal products
###


# create a df of no mezcal
no_mezcal = iowa[iowa['Category Name'] != 'MEZCAL']

# take the mezcal entries, get the store names
no_mezcal = pd.DataFrame(no_mezcal['Store Name'].unique())

#rename the store name column
no_mezcal = no_mezcal.rename(columns={0:'Store Name'})

# merge the two df's about mezcal
ranking = pd.concat([ranking, no_mezcal], ignore_index=True)

# fill nan's created in the join
ranking = ranking.fillna(0)

# rank them and store that in 
ranking['mezcal_bottles_rank'] = ranking['Bottles Sold'].rank(ascending = 0)
ranking['mezcal_variety_rank'] = ranking['Item Description'].rank(ascending = 0)

# create a ranking average, add them together divide by 2
ranking['total_ranking'] = (ranking['mezcal_bottles_rank'] + ranking['mezcal_variety_rank']) / 2

# %%
ranking.sort_values('total_ranking')
# Out:
#                                       Store Name  Bottles Sold  \
# 1                   Hy-vee #3 / bdi / des moines        2852.0
# 2                      Central city liquor, inc.        1493.0
# 0                                 Central city 2        2966.0
# 5                         Hy-vee # 6/ des moines         484.0
# 4                  Ingersoll liquor and beverage         678.0
# ..                                           ...           ...
# 223                                Scott's foods           0.0
# 222         Casey's general store #3422 / norwal           0.0
# 221            Kum & go #240 / north ave norwalk           0.0
# 219                       Kum & go #28 / norwalk           0.0
# 512  Casey's general store #2406 / pleasant hill           0.0
#
#      Item Description  mezcal_bottles_rank  mezcal_variety_rank  total_ranking
# 1                27.0                  2.0                  1.0           1.50
# 2                25.0                  3.0                  2.0           2.50
# 0                12.0                  1.0                  6.5           3.75
# 5                18.0                  6.0                  3.5           4.75
# 4                13.0                  5.0                  5.0           5.00
# ..                ...                  ...                  ...            ...
# 223               0.0                300.5                300.5         300.50
# 222               0.0                300.5                300.5         300.50
# 221               0.0                300.5                300.5         300.50
# 219               0.0                300.5                300.5         300.50
# 512               0.0                300.5                300.5         300.50
#
# [513 rows x 6 columns]

# %% [markdown]
# ### Pre Processing 4: One Hot Encoding categorical data

# %%
# create numerical data for categorical data

one_hot = OneHotEncoder(sparse=False)

# create a df for the one hotted columns
iowa_one_hot = pd.DataFrame(one_hot.fit_transform(iowa[['City', 'County', 'Bottle Price Category', 'Zip Code']]))

iowa_one_hot.columns = one_hot.get_feature_names_out(['City', 'County', 'Bottle Price Category', 'Zip Code'])

# merge the one hot columns to the rest of the df
one_hot_iowa = pd.concat([iowa, iowa_one_hot])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/70/gq6zfpsx5rg7k0vsvcbg70_40000gn/T/ipykernel_56846/628532384.py in <module>
#       6 iowa_one_hot = pd.DataFrame(one_hot.fit_transform(iowa[['City', 'County', 'Bottle Price Category', 'Zip Code']]))
#       7
# ----> 8 iowa_one_hot.columns = one_hot.get_feature_names_out(['City', 'County', 'Bottle Price Category', 'Zip Code'])
#       9 # merge the one hot columns to the rest of the df
#      10 iowa = iowa.join(iowa_one_hot)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 1 elements, new values have 105 elements

# %% [markdown]
# ### Pre Processing 4: Test Train Split

# %% [markdown]
# ### Pre Processing 5: Standard Scaler

# %%
scaler = StandardScaler()
scaler.fit_transform(iowa[['Bottle Volume (ml)', 'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold', 'Sale (Dollars)', 'Volume Sold (Liters)', 'Profit / Item', 'Profit / ml']])
